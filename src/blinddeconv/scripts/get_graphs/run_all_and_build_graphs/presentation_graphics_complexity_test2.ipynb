# %% [markdown]
# # Эксперименты и графики для одного алгоритма слепой деконволюции
#
# Ноутбук для прогона конкретного алгоритма на тестовых датасетах и построения индивидуальных графиков.
#
# **Инструкция по использованию:**
# 1. **Ячейка 2 (Настройка)** — задать алгоритм, параметры, пути к папкам
# 2. **Ячейки 3–4 (Датасет)** — настройка датасета + прогон. Копировать эту пару для каждого нового датасета
# 3. **Последняя ячейка** — финальная сводка по всем датасетам для данного алгоритма

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 1. Общая настройка ноутбука: алгоритм, пути, параметры
# ══════════════════════════════════════════════════════════════════════════════
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from pathlib import Path
from typing import Optional, Dict, List, Tuple
import visualisation as vis  # <-- все графики и TeX-генерация


# ── Автоопределение корня проекта ────────────────────────────────────────────
# Работает независимо от того, где лежит ноутбук: ищем pyproject.toml или src/
_nb_dir = Path(os.path.abspath("")).resolve()
PROJECT_ROOT = _nb_dir
for _p in [_nb_dir] + list(_nb_dir.parents):
    if (_p / "pyproject.toml").exists() or (_p / "src").is_dir():
        PROJECT_ROOT = _p
        break

sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / "src"))
os.chdir(PROJECT_ROOT)



# ── Настраиваемые параметры ──────────────────────────────────────────────────
ALGORITHM_LABEL = "PMP"   # <-- Менять для каждого алгоритма

# DATASETS_ROOT = PROJECT_ROOT / "validate_images"
DATASETS_ROOT = PROJECT_ROOT / "images" / "compare_data"
RESULTS_ROOT  = PROJECT_ROOT / "presentation_graphics"
RESULTS_ROOT.mkdir(parents=True, exist_ok=True)
ALG_RESULTS_DIR = RESULTS_ROOT / ALGORITHM_LABEL.replace(" ", "_")
ALG_RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# ── Параллелизация ───────────────────────────────────────────────────────────
NUM_WORKERS = 6  # Число параллельных процессов (1 = последовательно)

# --- Алгоритм: модуль / класс / параметры (для параллельного воркера) ---
ALG_MODULE = "src.blinddeconv.algorithms.blind_deconvolution.our_company.patch_wise_minimum_pixels_prior.pmp_cython_pyd.pmp"
ALG_CLASS = "PMP_BD"
ALG_KERNEL_PARAM = "kernel_size"  # имя аргумента размера ядра в конструкторе
ALG_KWARGS = {
    'kernel_size': 51, 
    'denoise_eps': 0.006, 
    'denoise_radius': 2,
    'lambda_tv': 0.005, 
    'lambda_l0': 0.002, 
    'grad_smooth_sigma': 0.285, 
    'ensemble_denoise': True,
    'impulse_preprocess': 'auto',
    'noise_estimation': 'pca',
    # 'act_params': 'auto',
    'preprocess': 'bm3d',
    'blind_denoise': 'guided',
    'pre_nonblind': 'bm3d',
             
}
from src.blinddeconv.algorithms.blind_deconvolution.our_company.patch_wise_minimum_pixels_prior.pmp_cython_pyd.pmp import PMP_BD

def create_algorithm(kernel_shape=(51, 51)):
    """Создаёт экземпляр алгоритма (для интерактивного использования)."""
    kw = dict(ALG_KWARGS)
    kw[ALG_KERNEL_PARAM] = kernel_shape
    return PMP_BD(**kw)

# def create_algorithm(kernel_shape=(31, 31)):
#     """Создаёт экземпляр алгоритма (для интерактивного использования)."""
#     alg = 
#     return alg

# ── Утилиты ──────────────────────────────────────────────────────────────────

def parse_distorted_name(filename: str) -> Tuple[Optional[str], Optional[str], Optional[str]]:
    stem = Path(filename).stem
    parts = stem.split("_")
    if len(parts) >= 2:
        return parts[0], parts[1], "_".join(parts[2:]) if len(parts) > 2 else ""
    return stem, None, None

def find_kernel_for_image(kernel_dir: Path, kernel_name: str) -> Optional[Path]:
    if not kernel_dir.exists():
        return None
    for f in kernel_dir.iterdir():
        if f.is_file() and kernel_name in f.stem:
            return f
    return None

def error_ratio_nonblind(original, blurred, true_kernel, est_kernel) -> float:
    """error ratio = MSE(Wiener с est_kernel) / MSE(Wiener с true_kernel)."""
    from numpy.fft import fft2, ifft2
    h, w = blurred.shape[:2]
    reg = 1e-3
    def _wr(y, k):
        K = fft2(k, s=(h, w)); Y = fft2(y, s=(h, w))
        return np.real(ifft2(np.conj(K) * Y / (np.abs(K)**2 + reg)))
    x_true = _wr(blurred, true_kernel)
    x_est  = _wr(blurred, est_kernel)
    orig = original.astype(np.float64)
    mse_true = np.mean((orig - x_true)**2)
    mse_est  = np.mean((orig - x_est)**2)
    return mse_est / mse_true if mse_true > 1e-12 else 1.0

# ── matplotlib настройки ─────────────────────────────────────────────────────
plt.rcParams.update({'font.size': 12, 'figure.dpi': 120,
                     'savefig.dpi': 150, 'savefig.bbox': 'tight'})

ALL_DATASET_RESULTS: List[Dict] = []

print(f"Алгоритм: {ALGORITHM_LABEL}")
print(f"Папка наборов данных: {DATASETS_ROOT}")
print(f"Папка результатов: {ALG_RESULTS_DIR}")
# Out:
# Алгоритм: PMP
# Папка наборов данных: D:\for_proga\franework_deconvolution\framework (9)\images\compare_data
# Папка результатов: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2a. Настройка текущего датасета
# ══════════════════════════════════════════════════════════════════════════════
DATASET_NAME = "Grid_Test"   # <-- Менять для другого датасета
DATASET_DIR = DATASETS_ROOT / DATASET_NAME

# Папки датасета
DIST_DIR   = DATASET_DIR / "distorted"
ORIG_DIR   = DATASET_DIR / "originals"
KERNEL_DIR = DATASET_DIR / "ground_truth_filters"

# Проверяем наличие
has_originals = ORIG_DIR.exists() and any(ORIG_DIR.iterdir())
has_kernels   = KERNEL_DIR.exists() and any(KERNEL_DIR.iterdir())
has_distorted = DIST_DIR.exists() and any(DIST_DIR.iterdir())

# Папка для результатов этого датасета
DS_RESULT_DIR = ALG_RESULTS_DIR / DATASET_NAME
DS_RESULT_DIR.mkdir(parents=True, exist_ok=True)
(DS_RESULT_DIR / "restored").mkdir(exist_ok=True)
(DS_RESULT_DIR / "kernels").mkdir(exist_ok=True)

print(f"Датасет: {DATASET_NAME}")
print(f"  Искажённые: {has_distorted}  |  Оригиналы: {has_originals}  |  GT ядра: {has_kernels}")
print(f"  Результаты → {DS_RESULT_DIR}")
# Out:
# Датасет: Grid_Test
#   Искажённые: True  |  Оригиналы: True  |  GT ядра: True
#   Результаты → D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\Grid_Test

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2b. Прогон алгоритма на датасете (параллельно)
# ══════════════════════════════════════════════════════════════════════════════
import importlib
import _process_worker; importlib.reload(_process_worker)
from concurrent.futures import ProcessPoolExecutor, as_completed

distorted_files = sorted([f for f in DIST_DIR.iterdir() if f.is_file()])
print(f"Найдено {len(distorted_files)} искажённых изображений  |  Воркеров: {NUM_WORKERS}\n")

# Формируем задания
# Если это датасет для замеров сложности, делаем 5 прогонов
# runs = 5 if DATASET_NAME in["Complexity_Test", "Grid_Test"] else 1
runs = 5 if DATASET_NAME in["Complexity_Test"] else 1


tasks =[]
for dist_file in distorted_files:
    tasks.append({
        'project_root': str(PROJECT_ROOT),
        'dist_file': str(dist_file),
        'orig_dir': str(ORIG_DIR),
        'kernel_dir': str(KERNEL_DIR),
        'has_originals': has_originals,
        'has_kernels': has_kernels,
        'dataset_name': DATASET_NAME,
        'algorithm_label': ALGORITHM_LABEL,
        'alg_module': ALG_MODULE,
        'alg_class': ALG_CLASS,
        'alg_kwargs': ALG_KWARGS,
        'alg_kernel_param': ALG_KERNEL_PARAM,
        'ds_result_dir': str(DS_RESULT_DIR),
        'num_runs': runs  # <--- ПЕРЕДАЕМ КОЛИЧЕСТВО ПРОГОНОВ
    })

# Параллельный / последовательный запуск
results_rows = []
if NUM_WORKERS > 1:
    with ProcessPoolExecutor(
        max_workers=NUM_WORKERS,
        initializer=_process_worker.init_worker,
        initargs=(str(PROJECT_ROOT),),
    ) as pool:
        futures = {pool.submit(_process_worker.process_one, t): t for t in tasks}
        for future in as_completed(futures):
            r = future.result()
            if r is None:
                fname = Path(futures[future]['dist_file']).name
                print(f"✗ {fname}: не удалось загрузить")
            elif 'error' in r:
                print(f"✗ {r['dist_file']}: {r['error']}")
            else:
                results_rows.append(r)
                psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
                er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
                print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")
else:
    for t in tasks:
        r = _process_worker.process_one(t)
        if r is None:
            print(f"✗ {Path(t['dist_file']).name}: не удалось загрузить")
        elif 'error' in r:
            print(f"✗ {r['dist_file']}: {r['error']}")
        else:
            results_rows.append(r)
            psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
            er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
            print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")

# Сохранение CSV
df_results = pd.DataFrame(results_rows)
csv_path = DS_RESULT_DIR / f"results_{ALGORITHM_LABEL}_{DATASET_NAME}.csv"
df_results.to_csv(csv_path, index=False)
print(f"\n{'─'*60}\nОбработано: {len(results_rows)}/{len(tasks)}  |  CSV: {csv_path}")
display(df_results)

# Запуск генерации красивых картинок 2x4
vis.save_complex_plots(
    df=df_results, 
    dist_dir=DIST_DIR, 
    save_dir=DS_RESULT_DIR / "complex_plots", 
    alg_label=ALGORITHM_LABEL
)

# Добавляем в общий список
ALL_DATASET_RESULTS.append({
    'dataset': DATASET_NAME,
    'df': df_results.copy(),
    'dir': DS_RESULT_DIR,
    'has_originals': has_originals,
    'has_kernels': has_kernels,
})
# Out:
# Найдено 50 искажённых изображений  |  Воркеров: 6
#
# ✓ airplane_linear_impulse.png  PSNR=21.94  ER=1.27  t=24.1с
# ✓ boat_dendric_gaussian.png  PSNR=17.05  ER=2.15  t=25.3с
# ✓ airplane_defocus_.png  PSNR=22.82  ER=0.98  t=30.6с
# ✓ boat_moon_gaussian.png  PSNR=17.26  ER=0.93  t=37.9с
# ✓ airplane_heliod_gaussian.png  PSNR=18.33  ER=1.04  t=39.8с
# ✓ boat_comet_gaussian.png  PSNR=18.14  ER=1.95  t=41.6с
# ✓ boat_wspiral_.png  PSNR=19.50  ER=1.30  t=35.8с
# ✓ boy_hookdefocus_brown.png  PSNR=18.22  ER=1.19  t=36.0с
# ✓ bridge_dendric_.png  PSNR=18.73  ER=1.11  t=23.3с
# ✓ boy_linear_poisson.png  PSNR=27.24  ER=1.22  t=40.5с
# ✓ boy_spiral_.png  PSNR=18.95  ER=0.98  t=35.3с
# ✓ bridge_comet_brown.png  PSNR=19.12  ER=1.36  t=37.0с
# ✓ cameraman_linear_.png  PSNR=22.57  ER=1.32  t=19.5с
# ✓ bridge_largemation_.png  PSNR=23.03  ER=1.09  t=32.2с
# ✓ bridge_wspiral_brown.png  PSNR=19.47  ER=1.18  t=44.5с
# ✓ cameraman_spiral_impulse.png  PSNR=18.08  ER=0.99  t=35.2с
# ✓ cameraman_defocus_poisson.png  PSNR=23.25  ER=1.26  t=44.7с
# ✓ childs_comet_poisson.png  PSNR=17.71  ER=1.90  t=42.2с
# ✓ childs_dendric_gaussian.png  PSNR=21.98  ER=2.09  t=32.3с
# ✓ childs_moon_.png  PSNR=19.98  ER=1.22  t=38.7с
# ✓ drawing_defocus_pink.png  PSNR=27.63  ER=1.39  t=31.5с
# ✓ drawing_spiral_.png  PSNR=19.06  ER=0.86  t=35.5с
# ✓ drawing_hookdefocus_poisson.png  PSNR=17.84  ER=1.02  t=44.2с
# ✓ house_moon_.png  PSNR=19.66  ER=1.11  t=36.0с
# ✓ house_largemation_poisson.png  PSNR=23.91  ER=1.05  t=42.6с
# ✓ house_wspiral_impulse.png  PSNR=21.94  ER=0.81  t=40.1с
# ✓ lenna_defocus_gaussian.png  PSNR=26.49  ER=1.74  t=34.1с
# ✓ lenna_linear_pink.png  PSNR=24.22  ER=1.18  t=43.0с
# ✓ lenna_heliod_.png  PSNR=20.47  ER=1.06  t=50.0с
# ✓ lenna_spiral_gaussian.png  PSNR=19.20  ER=0.95  t=53.6с
# ✓ monarch_dendric_brown.png  PSNR=15.19  ER=0.77  t=43.9с
# ✓ monarch_comet_.png  PSNR=17.01  ER=1.17  t=59.7с
# ✓ monarch_largemation_pink.png  PSNR=18.67  ER=0.95  t=51.2с
# ✓ parrot_heliod_.png  PSNR=17.35  ER=1.00  t=38.2с
# ✓ parrot_linear_poisson.png  PSNR=22.05  ER=1.15  t=39.3с
# ✓ people_dendric_brown.png  PSNR=18.78  ER=1.67  t=22.7с
# ✓ parrot_spiral_.png  PSNR=15.05  ER=1.61  t=40.1с
# ✓ people_moon_pink.png  PSNR=20.32  ER=1.08  t=31.2с
# ✓ people_comet_pink.png  PSNR=19.31  ER=1.73  t=39.9с
# ✓ pepper_defocus_brown.png  PSNR=23.64  ER=1.25  t=39.2с
# ✓ people_wspiral_.png  PSNR=20.15  ER=1.22  t=41.7с
# ✓ pepper_linear_pink.png  PSNR=22.87  ER=1.13  t=30.4с
# ✓ pepper_hookdefocus_impulse.png  PSNR=17.69  ER=0.99  t=40.8с
# ✓ pepper_spiral_.png  PSNR=16.71  ER=0.91  t=45.9с
# ✓ scarf_dendric_.png  PSNR=19.55  ER=2.79  t=31.1с
# ✓ scarf_largemation_impulse.png  PSNR=21.73  ER=1.19  t=58.2с
# ✓ scarf_comet_poisson.png  PSNR=20.09  ER=1.88  t=79.0с
# ✓ star_heliod_.png  PSNR=18.37  ER=1.03  t=63.3с
# ✓ star_hookdefocus_impulse.png  PSNR=17.30  ER=1.19  t=61.7с
# ✓ star_spiral_impulse.png  PSNR=17.03  ER=0.91  t=49.8с
#
# ────────────────────────────────────────────────────────────
# Обработано: 50/50  |  CSV: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\Grid_Test\results_PMP_Grid_Test.csv
#       dataset                   distorted_file image_name  kernel_name  \
# 0   Grid_Test      airplane_linear_impulse.png   airplane       linear
# 1   Grid_Test        boat_dendric_gaussian.png       boat      dendric
# 2   Grid_Test            airplane_defocus_.png   airplane      defocus
# 3   Grid_Test           boat_moon_gaussian.png       boat         moon
# 4   Grid_Test     airplane_heliod_gaussian.png   airplane       heliod
# 5   Grid_Test          boat_comet_gaussian.png       boat        comet
# 6   Grid_Test                boat_wspiral_.png       boat      wspiral
# 7   Grid_Test        boy_hookdefocus_brown.png        boy  hookdefocus
# 8   Grid_Test              bridge_dendric_.png     bridge      dendric
# 9   Grid_Test           boy_linear_poisson.png        boy       linear
# 10  Grid_Test                  boy_spiral_.png        boy       spiral
# 11  Grid_Test           bridge_comet_brown.png     bridge        comet
# 12  Grid_Test            cameraman_linear_.png  cameraman       linear
# 13  Grid_Test          bridge_largemation_.png     bridge  largemation
# 14  Grid_Test         bridge_wspiral_brown.png     bridge      wspiral
# 15  Grid_Test     cameraman_spiral_impulse.png  cameraman       spiral
# 16  Grid_Test    cameraman_defocus_poisson.png  cameraman      defocus
# 17  Grid_Test         childs_comet_poisson.png     childs        comet
# 18  Grid_Test      childs_dendric_gaussian.png     childs      dendric
# 19  Grid_Test                 childs_moon_.png     childs         moon
# 20  Grid_Test         drawing_defocus_pink.png    drawing      defocus
# 21  Grid_Test              drawing_spiral_.png    drawing       spiral
# 22  Grid_Test  drawing_hookdefocus_poisson.png    drawing  hookdefocus
# 23  Grid_Test                  house_moon_.png      house         moon
# 24  Grid_Test    house_largemation_poisson.png      house  largemation
# 25  Grid_Test        house_wspiral_impulse.png      house      wspiral
# 26  Grid_Test       lenna_defocus_gaussian.png      lenna      defocus
# 27  Grid_Test            lenna_linear_pink.png      lenna       linear
# 28  Grid_Test                lenna_heliod_.png      lenna       heliod
# 29  Grid_Test        lenna_spiral_gaussian.png      lenna       spiral
# 30  Grid_Test        monarch_dendric_brown.png    monarch      dendric
# 31  Grid_Test               monarch_comet_.png    monarch        comet
# 32  Grid_Test     monarch_largemation_pink.png    monarch  largemation
# 33  Grid_Test               parrot_heliod_.png     parrot       heliod
# 34  Grid_Test        parrot_linear_poisson.png     parrot       linear
# 35  Grid_Test         people_dendric_brown.png     people      dendric
# 36  Grid_Test               parrot_spiral_.png     parrot       spiral
# 37  Grid_Test             people_moon_pink.png     people         moon
# 38  Grid_Test            people_comet_pink.png     people        comet
# 39  Grid_Test         pepper_defocus_brown.png     pepper      defocus
# 40  Grid_Test              people_wspiral_.png     people      wspiral
# 41  Grid_Test           pepper_linear_pink.png     pepper       linear
# 42  Grid_Test   pepper_hookdefocus_impulse.png     pepper  hookdefocus
# 43  Grid_Test               pepper_spiral_.png     pepper       spiral
# 44  Grid_Test               scarf_dendric_.png      scarf      dendric
# 45  Grid_Test    scarf_largemation_impulse.png      scarf  largemation
# 46  Grid_Test          scarf_comet_poisson.png      scarf        comet
# 47  Grid_Test                 star_heliod_.png       star       heliod
# 48  Grid_Test     star_hookdefocus_impulse.png       star  hookdefocus
# 49  Grid_Test          star_spiral_impulse.png       star       spiral
#
#    noise_name kernel_shape  image_megapixels  time_sec  runs_count  \
# 0     impulse     (11, 11)             0.066    24.093           1
# 1    gaussian     (15, 15)             0.066    25.315           1
# 2                 (19, 19)             0.066    30.554           1
# 3    gaussian     (21, 21)             0.066    37.899           1
# 4    gaussian     (31, 31)             0.066    39.825           1
# 5    gaussian     (35, 35)             0.066    41.580           1
# 6                 (31, 31)             0.066    35.840           1
# 7       brown     (29, 29)             0.065    36.043           1
# 8                 (15, 15)             0.065    23.324           1
# 9     poisson     (11, 11)             0.065    40.458           1
# 10                (31, 31)             0.065    35.313           1
# 11      brown     (35, 35)             0.065    36.989           1
# 12                (11, 11)             0.066    19.545           1
# 13                (19, 13)             0.065    32.170           1
# 14      brown     (31, 31)             0.065    44.479           1
# 15    impulse     (31, 31)             0.066    35.248           1
# 16    poisson     (19, 19)             0.066    44.732           1
# 17    poisson     (35, 35)             0.065    42.216           1
# 18   gaussian     (15, 15)             0.065    32.344           1
# 19                (21, 21)             0.065    38.699           1
# 20       pink     (19, 19)             0.065    31.472           1
# 21                (31, 31)             0.065    35.548           1
# 22    poisson     (29, 29)             0.065    44.159           1
# 23                (21, 21)             0.066    35.968           1
# 24    poisson     (19, 13)             0.066    42.634           1
# 25    impulse     (31, 31)             0.066    40.114           1
# 26   gaussian     (19, 19)             0.066    34.066           1
# 27       pink     (11, 11)             0.066    42.985           1
# 28                (31, 31)             0.066    50.047           1
# 29   gaussian     (31, 31)             0.066    53.619           1
# 30      brown     (15, 15)             0.066    43.878           1
# 31                (35, 35)             0.066    59.708           1
# 32       pink     (19, 13)             0.066    51.229           1
# 33                (31, 31)             0.066    38.175           1
# 34    poisson     (11, 11)             0.066    39.314           1
# 35      brown     (15, 15)             0.066    22.726           1
# 36                (31, 31)             0.066    40.114           1
# 37       pink     (21, 21)             0.066    31.201           1
# 38       pink     (35, 35)             0.066    39.922           1
# 39      brown     (19, 19)             0.066    39.235           1
# 40                (31, 31)             0.066    41.682           1
# 41       pink     (11, 11)             0.066    30.418           1
# 42    impulse     (29, 29)             0.066    40.814           1
# 43                (31, 31)             0.066    45.872           1
# 44                (15, 15)             0.066    31.061           1
# 45    impulse     (19, 13)             0.066    58.170           1
# 46    poisson     (35, 35)             0.066    78.962           1
# 47                (31, 31)             0.066    63.269           1
# 48    impulse     (29, 29)             0.066    61.738           1
# 49    impulse     (31, 31)             0.066    49.754           1
#
#                                         restored_path  \
# 0   D:\for_proga\franework_deconvolution\framework...
# 1   D:\for_proga\franework_deconvolution\framework...
# 2   D:\for_proga\franework_deconvolution\framework...
# 3   D:\for_proga\franework_deconvolution\framework...
# 4   D:\for_proga\franework_deconvolution\framework...
# 5   D:\for_proga\franework_deconvolution\framework...
# 6   D:\for_proga\franework_deconvolution\framework...
# 7   D:\for_proga\franework_deconvolution\framework...
# 8   D:\for_proga\franework_deconvolution\framework...
# 9   D:\for_proga\franework_deconvolution\framework...
# 10  D:\for_proga\franework_deconvolution\framework...
# 11  D:\for_proga\franework_deconvolution\framework...
# 12  D:\for_proga\franework_deconvolution\framework...
# 13  D:\for_proga\franework_deconvolution\framework...
# 14  D:\for_proga\franework_deconvolution\framework...
# 15  D:\for_proga\franework_deconvolution\framework...
# 16  D:\for_proga\franework_deconvolution\framework...
# 17  D:\for_proga\franework_deconvolution\framework...
# 18  D:\for_proga\franework_deconvolution\framework...
# 19  D:\for_proga\franework_deconvolution\framework...
# 20  D:\for_proga\franework_deconvolution\framework...
# 21  D:\for_proga\franework_deconvolution\framework...
# 22  D:\for_proga\franework_deconvolution\framework...
# 23  D:\for_proga\franework_deconvolution\framework...
# 24  D:\for_proga\franework_deconvolution\framework...
# 25  D:\for_proga\franework_deconvolution\framework...
# 26  D:\for_proga\franework_deconvolution\framework...
# 27  D:\for_proga\franework_deconvolution\framework...
# 28  D:\for_proga\franework_deconvolution\framework...
# 29  D:\for_proga\franework_deconvolution\framework...
# 30  D:\for_proga\franework_deconvolution\framework...
# 31  D:\for_proga\franework_deconvolution\framework...
# 32  D:\for_proga\franework_deconvolution\framework...
# 33  D:\for_proga\franework_deconvolution\framework...
# 34  D:\for_proga\franework_deconvolution\framework...
# 35  D:\for_proga\franework_deconvolution\framework...
# 36  D:\for_proga\franework_deconvolution\framework...
# 37  D:\for_proga\franework_deconvolution\framework...
# 38  D:\for_proga\franework_deconvolution\framework...
# 39  D:\for_proga\franework_deconvolution\framework...
# 40  D:\for_proga\franework_deconvolution\framework...
# 41  D:\for_proga\franework_deconvolution\framework...
# 42  D:\for_proga\franework_deconvolution\framework...
# 43  D:\for_proga\franework_deconvolution\framework...
# 44  D:\for_proga\franework_deconvolution\framework...
# 45  D:\for_proga\franework_deconvolution\framework...
# 46  D:\for_proga\franework_deconvolution\framework...
# 47  D:\for_proga\franework_deconvolution\framework...
# 48  D:\for_proga\franework_deconvolution\framework...
# 49  D:\for_proga\franework_deconvolution\framework...
#
#                                           kernel_path  \
# 0   D:\for_proga\franework_deconvolution\framework...
# 1   D:\for_proga\franework_deconvolution\framework...
# 2   D:\for_proga\franework_deconvolution\framework...
# 3   D:\for_proga\franework_deconvolution\framework...
# 4   D:\for_proga\franework_deconvolution\framework...
# 5   D:\for_proga\franework_deconvolution\framework...
# 6   D:\for_proga\franework_deconvolution\framework...
# 7   D:\for_proga\franework_deconvolution\framework...
# 8   D:\for_proga\franework_deconvolution\framework...
# 9   D:\for_proga\franework_deconvolution\framework...
# 10  D:\for_proga\franework_deconvolution\framework...
# 11  D:\for_proga\franework_deconvolution\framework...
# 12  D:\for_proga\franework_deconvolution\framework...
# 13  D:\for_proga\franework_deconvolution\framework...
# 14  D:\for_proga\franework_deconvolution\framework...
# 15  D:\for_proga\franework_deconvolution\framework...
# 16  D:\for_proga\franework_deconvolution\framework...
# 17  D:\for_proga\franework_deconvolution\framework...
# 18  D:\for_proga\franework_deconvolution\framework...
# 19  D:\for_proga\franework_deconvolution\framework...
# 20  D:\for_proga\franework_deconvolution\framework...
# 21  D:\for_proga\franework_deconvolution\framework...
# 22  D:\for_proga\franework_deconvolution\framework...
# 23  D:\for_proga\franework_deconvolution\framework...
# 24  D:\for_proga\franework_deconvolution\framework...
# 25  D:\for_proga\franework_deconvolution\framework...
# 26  D:\for_proga\franework_deconvolution\framework...
# 27  D:\for_proga\franework_deconvolution\framework...
# 28  D:\for_proga\franework_deconvolution\framework...
# 29  D:\for_proga\franework_deconvolution\framework...
# 30  D:\for_proga\franework_deconvolution\framework...
# 31  D:\for_proga\franework_deconvolution\framework...
# 32  D:\for_proga\franework_deconvolution\framework...
# 33  D:\for_proga\franework_deconvolution\framework...
# 34  D:\for_proga\franework_deconvolution\framework...
# 35  D:\for_proga\franework_deconvolution\framework...
# 36  D:\for_proga\franework_deconvolution\framework...
# 37  D:\for_proga\franework_deconvolution\framework...
# 38  D:\for_proga\franework_deconvolution\framework...
# 39  D:\for_proga\franework_deconvolution\framework...
# 40  D:\for_proga\franework_deconvolution\framework...
# 41  D:\for_proga\franework_deconvolution\framework...
# 42  D:\for_proga\franework_deconvolution\framework...
# 43  D:\for_proga\franework_deconvolution\framework...
# 44  D:\for_proga\franework_deconvolution\framework...
# 45  D:\for_proga\franework_deconvolution\framework...
# 46  D:\for_proga\franework_deconvolution\framework...
# 47  D:\for_proga\franework_deconvolution\framework...
# 48  D:\for_proga\franework_deconvolution\framework...
# 49  D:\for_proga\franework_deconvolution\framework...
#
#                                        gt_kernel_path  \
# 0   D:\for_proga\franework_deconvolution\framework...
# 1   D:\for_proga\franework_deconvolution\framework...
# 2   D:\for_proga\franework_deconvolution\framework...
# 3   D:\for_proga\franework_deconvolution\framework...
# 4   D:\for_proga\franework_deconvolution\framework...
# 5   D:\for_proga\franework_deconvolution\framework...
# 6   D:\for_proga\franework_deconvolution\framework...
# 7   D:\for_proga\franework_deconvolution\framework...
# 8   D:\for_proga\franework_deconvolution\framework...
# 9   D:\for_proga\franework_deconvolution\framework...
# 10  D:\for_proga\franework_deconvolution\framework...
# 11  D:\for_proga\franework_deconvolution\framework...
# 12  D:\for_proga\franework_deconvolution\framework...
# 13  D:\for_proga\franework_deconvolution\framework...
# 14  D:\for_proga\franework_deconvolution\framework...
# 15  D:\for_proga\franework_deconvolution\framework...
# 16  D:\for_proga\franework_deconvolution\framework...
# 17  D:\for_proga\franework_deconvolution\framework...
# 18  D:\for_proga\franework_deconvolution\framework...
# 19  D:\for_proga\franework_deconvolution\framework...
# 20  D:\for_proga\franework_deconvolution\framework...
# 21  D:\for_proga\franework_deconvolution\framework...
# 22  D:\for_proga\franework_deconvolution\framework...
# 23  D:\for_proga\franework_deconvolution\framework...
# 24  D:\for_proga\franework_deconvolution\framework...
# 25  D:\for_proga\franework_deconvolution\framework...
# 26  D:\for_proga\franework_deconvolution\framework...
# 27  D:\for_proga\franework_deconvolution\framework...
# 28  D:\for_proga\franework_deconvolution\framework...
# 29  D:\for_proga\franework_deconvolution\framework...
# 30  D:\for_proga\franework_deconvolution\framework...
# 31  D:\for_proga\franework_deconvolution\framework...
# 32  D:\for_proga\franework_deconvolution\framework...
# 33  D:\for_proga\franework_deconvolution\framework...
# 34  D:\for_proga\franework_deconvolution\framework...
# 35  D:\for_proga\franework_deconvolution\framework...
# 36  D:\for_proga\franework_deconvolution\framework...
# 37  D:\for_proga\franework_deconvolution\framework...
# 38  D:\for_proga\franework_deconvolution\framework...
# 39  D:\for_proga\franework_deconvolution\framework...
# 40  D:\for_proga\franework_deconvolution\framework...
# 41  D:\for_proga\franework_deconvolution\framework...
# 42  D:\for_proga\franework_deconvolution\framework...
# 43  D:\for_proga\franework_deconvolution\framework...
# 44  D:\for_proga\franework_deconvolution\framework...
# 45  D:\for_proga\franework_deconvolution\framework...
# 46  D:\for_proga\franework_deconvolution\framework...
# 47  D:\for_proga\franework_deconvolution\framework...
# 48  D:\for_proga\franework_deconvolution\framework...
# 49  D:\for_proga\franework_deconvolution\framework...
#
#                                         original_path     psnr    ssim  \
# 0   D:\for_proga\franework_deconvolution\framework...  21.9446  0.7340
# 1   D:\for_proga\franework_deconvolution\framework...  17.0473  0.4022
# 2   D:\for_proga\franework_deconvolution\framework...  22.8211  0.7577
# 3   D:\for_proga\franework_deconvolution\framework...  17.2629  0.3155
# 4   D:\for_proga\franework_deconvolution\framework...  18.3290  0.5251
# 5   D:\for_proga\franework_deconvolution\framework...  18.1412  0.4000
# 6   D:\for_proga\franework_deconvolution\framework...  19.5042  0.4744
# 7   D:\for_proga\franework_deconvolution\framework...  18.2203  0.3995
# 8   D:\for_proga\franework_deconvolution\framework...  18.7286  0.4114
# 9   D:\for_proga\franework_deconvolution\framework...  27.2425  0.8182
# 10  D:\for_proga\franework_deconvolution\framework...  18.9531  0.4003
# 11  D:\for_proga\franework_deconvolution\framework...  19.1199  0.4043
# 12  D:\for_proga\franework_deconvolution\framework...  22.5730  0.7400
# 13  D:\for_proga\franework_deconvolution\framework...  23.0291  0.6218
# 14  D:\for_proga\franework_deconvolution\framework...  19.4670  0.4158
# 15  D:\for_proga\franework_deconvolution\framework...  18.0815  0.5366
# 16  D:\for_proga\franework_deconvolution\framework...  23.2487  0.7466
# 17  D:\for_proga\franework_deconvolution\framework...  17.7123  0.4896
# 18  D:\for_proga\franework_deconvolution\framework...  21.9771  0.6310
# 19  D:\for_proga\franework_deconvolution\framework...  19.9843  0.5431
# 20  D:\for_proga\franework_deconvolution\framework...  27.6323  0.8619
# 21  D:\for_proga\franework_deconvolution\framework...  19.0568  0.5018
# 22  D:\for_proga\franework_deconvolution\framework...  17.8388  0.4059
# 23  D:\for_proga\franework_deconvolution\framework...  19.6625  0.5681
# 24  D:\for_proga\franework_deconvolution\framework...  23.9118  0.6943
# 25  D:\for_proga\franework_deconvolution\framework...  21.9406  0.6660
# 26  D:\for_proga\franework_deconvolution\framework...  26.4881  0.7378
# 27  D:\for_proga\franework_deconvolution\framework...  24.2167  0.6573
# 28  D:\for_proga\franework_deconvolution\framework...  20.4749  0.4680
# 29  D:\for_proga\franework_deconvolution\framework...  19.2029  0.4153
# 30  D:\for_proga\franework_deconvolution\framework...  15.1863  0.2995
# 31  D:\for_proga\franework_deconvolution\framework...  17.0057  0.4776
# 32  D:\for_proga\franework_deconvolution\framework...  18.6679  0.5973
# 33  D:\for_proga\franework_deconvolution\framework...  17.3462  0.5419
# 34  D:\for_proga\franework_deconvolution\framework...  22.0507  0.7517
# 35  D:\for_proga\franework_deconvolution\framework...  18.7829  0.2965
# 36  D:\for_proga\franework_deconvolution\framework...  15.0548  0.4831
# 37  D:\for_proga\franework_deconvolution\framework...  20.3239  0.4214
# 38  D:\for_proga\franework_deconvolution\framework...  19.3109  0.3499
# 39  D:\for_proga\franework_deconvolution\framework...  23.6355  0.7921
# 40  D:\for_proga\franework_deconvolution\framework...  20.1549  0.4304
# 41  D:\for_proga\franework_deconvolution\framework...  22.8693  0.7572
# 42  D:\for_proga\franework_deconvolution\framework...  17.6871  0.5009
# 43  D:\for_proga\franework_deconvolution\framework...  16.7104  0.3822
# 44  D:\for_proga\franework_deconvolution\framework...  19.5521  0.4234
# 45  D:\for_proga\franework_deconvolution\framework...  21.7332  0.5944
# 46  D:\for_proga\franework_deconvolution\framework...  20.0853  0.4756
# 47  D:\for_proga\franework_deconvolution\framework...  18.3731  0.3950
# 48  D:\for_proga\franework_deconvolution\framework...  17.2954  0.3634
# 49  D:\for_proga\franework_deconvolution\framework...  17.0284  0.2767
#
#     psnr_blurred  ssim_blurred  error_ratio
# 0        19.1471        0.4986       1.2747
# 1        18.3803        0.3072       2.1542
# 2        22.3396        0.7369       0.9803
# 3        17.5489        0.2818       0.9339
# 4        17.5145        0.3800       1.0377
# 5        17.9269        0.3362       1.9488
# 6        18.0720        0.3861       1.2988
# 7        19.9749        0.4680       1.1891
# 8        19.3336        0.3758       1.1145
# 9        26.5987        0.7673       1.2206
# 10       19.9266        0.5175       0.9760
# 11       19.0144        0.3731       1.3649
# 12       20.7172        0.6486       1.3177
# 13       20.8287        0.4997       1.0904
# 14       18.6420        0.3420       1.1806
# 15       17.2786        0.3806       0.9893
# 16       22.4501        0.6342       1.2564
# 17       17.8743        0.4362       1.9020
# 18       18.8348        0.3962       2.0888
# 19       17.0645        0.3326       1.2181
# 20       25.5866        0.7392       1.3934
# 21       18.2830        0.4337       0.8638
# 22       18.5570        0.4098       1.0171
# 23       19.5530        0.5175       1.1117
# 24       22.3872        0.5313       1.0520
# 25       19.1612        0.4162       0.8108
# 26       25.2761        0.6487       1.7381
# 27       22.5048        0.5174       1.1791
# 28       19.5075        0.4332       1.0587
# 29       19.4389        0.3680       0.9456
# 30       16.3546        0.3621       0.7712
# 31       16.6829        0.4330       1.1739
# 32       18.2142        0.5069       0.9495
# 33       16.4756        0.4838       1.0007
# 34       19.1945        0.6052       1.1459
# 35       19.3427        0.2696       1.6695
# 36       16.3966        0.4787       1.6127
# 37       18.8191        0.2448       1.0758
# 38       19.3684        0.3055       1.7349
# 39       23.0267        0.7452       1.2496
# 40       19.4837        0.3529       1.2155
# 41       20.7300        0.5873       1.1267
# 42       17.4974        0.3868       0.9925
# 43       17.4283        0.4685       0.9143
# 44       20.5858        0.4557       2.7871
# 45       21.1101        0.4893       1.1892
# 46       20.0094        0.4067       1.8796
# 47       17.7819        0.3416       1.0302
# 48       17.3390        0.2965       1.1934
# 49       17.1704        0.2912       0.9073
#   Генерация комплексных изображений (50 шт.). Пожалуйста, подождите...
#   Готово! Сохранено 50 изображений в: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\Grid_Test\complex_plots

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2a. Настройка текущего датасета
# ══════════════════════════════════════════════════════════════════════════════
DATASET_NAME = "Complexity_Test"   # <-- Менять для другого датасета
DATASET_DIR = DATASETS_ROOT / DATASET_NAME

# Папки датасета
DIST_DIR   = DATASET_DIR / "distorted"
ORIG_DIR   = DATASET_DIR / "originals"
KERNEL_DIR = DATASET_DIR / "ground_truth_filters"

# Проверяем наличие
has_originals = ORIG_DIR.exists() and any(ORIG_DIR.iterdir())
has_kernels   = KERNEL_DIR.exists() and any(KERNEL_DIR.iterdir())
has_distorted = DIST_DIR.exists() and any(DIST_DIR.iterdir())

# Папка для результатов этого датасета
DS_RESULT_DIR = ALG_RESULTS_DIR / DATASET_NAME
DS_RESULT_DIR.mkdir(parents=True, exist_ok=True)
(DS_RESULT_DIR / "restored").mkdir(exist_ok=True)
(DS_RESULT_DIR / "kernels").mkdir(exist_ok=True)

print(f"Датасет: {DATASET_NAME}")
print(f"  Искажённые: {has_distorted}  |  Оригиналы: {has_originals}  |  GT ядра: {has_kernels}")
print(f"  Результаты → {DS_RESULT_DIR}")
# Out:
# Датасет: Complexity_Test
#   Искажённые: True  |  Оригиналы: True  |  GT ядра: True
#   Результаты → D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\Complexity_Test

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2b. Прогон алгоритма на датасете (параллельно)
# ══════════════════════════════════════════════════════════════════════════════
import importlib
import _process_worker; importlib.reload(_process_worker)
from concurrent.futures import ProcessPoolExecutor, as_completed

distorted_files = sorted([f for f in DIST_DIR.iterdir() if f.is_file()])
print(f"Найдено {len(distorted_files)} искажённых изображений  |  Воркеров: {NUM_WORKERS}\n")

# Формируем задания
# Если это датасет для замеров сложности, делаем 5 прогонов
runs = 5 if DATASET_NAME in["Complexity_Test", "Grid_Test"] else 1

tasks =[]
for dist_file in distorted_files:
    tasks.append({
        'project_root': str(PROJECT_ROOT),
        'dist_file': str(dist_file),
        'orig_dir': str(ORIG_DIR),
        'kernel_dir': str(KERNEL_DIR),
        'has_originals': has_originals,
        'has_kernels': has_kernels,
        'dataset_name': DATASET_NAME,
        'algorithm_label': ALGORITHM_LABEL,
        'alg_module': ALG_MODULE,
        'alg_class': ALG_CLASS,
        'alg_kwargs': ALG_KWARGS,
        'alg_kernel_param': ALG_KERNEL_PARAM,
        'ds_result_dir': str(DS_RESULT_DIR),
        'num_runs': runs  # <--- ПЕРЕДАЕМ КОЛИЧЕСТВО ПРОГОНОВ
    })

# Параллельный / последовательный запуск
results_rows = []
if NUM_WORKERS > 1:
    with ProcessPoolExecutor(
        max_workers=NUM_WORKERS,
        initializer=_process_worker.init_worker,
        initargs=(str(PROJECT_ROOT),),
    ) as pool:
        futures = {pool.submit(_process_worker.process_one, t): t for t in tasks}
        for future in as_completed(futures):
            r = future.result()
            if r is None:
                fname = Path(futures[future]['dist_file']).name
                print(f"✗ {fname}: не удалось загрузить")
            elif 'error' in r:
                print(f"✗ {r['dist_file']}: {r['error']}")
            else:
                results_rows.append(r)
                psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
                er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
                print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")
else:
    for t in tasks:
        r = _process_worker.process_one(t)
        if r is None:
            print(f"✗ {Path(t['dist_file']).name}: не удалось загрузить")
        elif 'error' in r:
            print(f"✗ {r['dist_file']}: {r['error']}")
        else:
            results_rows.append(r)
            psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
            er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
            print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")

# Сохранение CSV
df_results = pd.DataFrame(results_rows)
csv_path = DS_RESULT_DIR / f"results_{ALGORITHM_LABEL}_{DATASET_NAME}.csv"
df_results.to_csv(csv_path, index=False)
print(f"\n{'─'*60}\nОбработано: {len(results_rows)}/{len(tasks)}  |  CSV: {csv_path}")
display(df_results)

# Запуск генерации красивых картинок 2x4
vis.save_complex_plots(
    df=df_results, 
    dist_dir=DIST_DIR, 
    save_dir=DS_RESULT_DIR / "complex_plots", 
    alg_label=ALGORITHM_LABEL
)

# Добавляем в общий список
ALL_DATASET_RESULTS.append({
    'dataset': DATASET_NAME,
    'df': df_results.copy(),
    'dir': DS_RESULT_DIR,
    'has_originals': has_originals,
    'has_kernels': has_kernels,
})
# Out:
# Найдено 2 искажённых изображений  |  Воркеров: 6
#
# ✓ boy_hookdefocus_kernel_gaussian.png  PSNR=19.61  ER=1.24  t=11.4с
# ✓ barbara_hookdefocus_kernel_gaussian.png  PSNR=20.29  ER=1.18  t=47.2с
#
# ────────────────────────────────────────────────────────────
# Обработано: 2/2  |  CSV: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\Complexity_Test\results_PMP_Complexity_Test.csv
#            dataset                           distorted_file image_name  \
# 0  Complexity_Test      boy_hookdefocus_kernel_gaussian.png        boy
# 1  Complexity_Test  barbara_hookdefocus_kernel_gaussian.png    barbara
#
#    kernel_name       noise_name kernel_shape  image_megapixels  time_sec  \
# 0  hookdefocus  kernel_gaussian     (29, 29)             0.065    11.357
# 1  hookdefocus  kernel_gaussian     (29, 29)             0.262    47.208
#
#    runs_count                                      restored_path  \
# 0           5  D:\for_proga\franework_deconvolution\framework...
# 1           5  D:\for_proga\franework_deconvolution\framework...
#
#                                          kernel_path  \
# 0  D:\for_proga\franework_deconvolution\framework...
# 1  D:\for_proga\franework_deconvolution\framework...
#
#                                       gt_kernel_path  \
# 0  D:\for_proga\franework_deconvolution\framework...
# 1  D:\for_proga\franework_deconvolution\framework...
#
#                                        original_path     psnr    ssim  \
# 0  D:\for_proga\franework_deconvolution\framework...  19.6134  0.4951
# 1  D:\for_proga\franework_deconvolution\framework...  20.2867  0.4982
#
#    psnr_blurred  ssim_blurred  error_ratio
# 0       19.9327        0.4193       1.2393
# 1       19.9949        0.3983       1.1767
#   Генерация комплексных изображений (2 шт.). Пожалуйста, подождите...
#   Готово! Сохранено 2 изображений в: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\Complexity_Test\complex_plots

# %% [markdown]
# ## Финальная сводка: графики и TeX для одного алгоритма
#
# Эта ячейка строит все индивидуальные графики по накопленным данным из `ALL_DATASET_RESULTS`.
#
# Графики:
# - 4. PSNR/SSIM в зависимости от итераций (если доступно)
# - 5. Сходимость ядра (если доступно)
# - 6. Гистограмма распределения error ratio
# - 7. Зависимость от шума (если в именах файлов есть информация)
# - 8. Зависимость от размера ядра
# - 2. Success Rate vs Error Ratio (если есть GT ядра)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 3. Финальная сводка для одного алгоритма
# ══════════════════════════════════════════════════════════════════════════════

# Объединяем все результаты
df_all = pd.concat([r['df'] for r in ALL_DATASET_RESULTS], ignore_index=True)
print(f"Всего обработано изображений: {len(df_all)}\n")

TEX_DIR = ALG_RESULTS_DIR / "tex"
TEX_DIR.mkdir(exist_ok=True)
FIG_DIR = ALG_RESULTS_DIR / "figures"
FIG_DIR.mkdir(exist_ok=True)

# ─── 9. Боксплоты PSNR/SSIM для одного метода по датасетам ──────────
vis.plot_boxplots_single(
    df_all, ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 14. Сравнение 1D-профилей ядер и карт разности ──────────────────
# Создадим отдельную папку для профилей, так как их будет сохранено много
PROFILES_DIR = ALG_RESULTS_DIR / "kernel_profiles"
vis.save_kernel_profiles_and_diff(
    df_all, DIST_DIR, PROFILES_DIR, ALGORITHM_LABEL
)
print(f"Профили ядер сохранены в: {PROFILES_DIR}")

# ─── 6. Гистограмма распределения отношения ошибки ───────────────────────────
vis.plot_error_ratio_histogram_single(
    df_all['error_ratio'], ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 2. Доля успешных / отношение ошибки ─────────────────────────────────────
vis.plot_success_rate_single(
    df_all['error_ratio'], ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 3. Столбчатая диаграмма PSNR / SSIM по изображениям ─────────────────────
vis.plot_psnr_ssim_bars_single(
    df_all, ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 8. Зависимость от размера ядра ──────────────────────────────────────────
vis.plot_kernel_size_dependency_single(
    df_all, ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 10 & 11. Итоговая таблица (с Суммарной строкой и экстремумами) ───────────
df_summary = vis.build_summary_single(
    ALL_DATASET_RESULTS, ALGORITHM_LABEL, tex_dir=TEX_DIR
)
display(df_summary)

# Сохраняем объединённый CSV
df_all.to_csv(ALG_RESULTS_DIR / f"all_results_{ALGORITHM_LABEL}.csv", index=False)
print(f"\nОбщий CSV: {ALG_RESULTS_DIR / f'all_results_{ALGORITHM_LABEL}.csv'}")
# Out:
# Всего обработано изображений: 52
#   Генерация профилей ядер (52 шт.). Пожалуйста, подождите...
# Профили ядер сохранены в: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\kernel_profiles
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\tex\error_ratio_histogram.tex
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\tex\success_rate.tex
# 2026-04-18 18:20:33,886 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-18 18:20:33,888 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-18 18:20:33,893 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-18 18:20:33,893 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\tex\psnr_ssim_bar.tex
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\tex\kernel_size_dependency.tex
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\tex\summary_table.tex
#       Набор данных  Количество искаженных изображений Размер изображения  \
# 0        Grid_Test                                 50            256x256
# 1  Complexity_Test                                  2            255x255
# 2   ВСЕ (Суммарно)                                 52          Различные
#
#    PSNR (исх.)  Среднее (PSNR) Δ PSNR  Медиана (PSNR)  Максимум (PSNR)  \
# 0        19.45           20.05  +0.60           19.39            27.63
# 1        19.96           19.95  -0.01           19.95            20.29
# 2        19.47           20.05  +0.58           19.49            27.63
#
#                       Лучший случай (PSNR)  Минимум (PSNR)  ... SSIM (исх.)  \
# 0                 drawing_defocus_pink.png           15.05  ...      0.4525
# 1  barbara_hookdefocus_kernel_gaussian.png           19.61  ...      0.4088
# 2                 drawing_defocus_pink.png           15.05  ...      0.4508
#
#    Среднее (SSIM)   Δ SSIM Медиана (SSIM)  Максимум (SSIM)  \
# 0          0.5271  +0.0746         0.4863           0.8619
# 1          0.4966  +0.0878         0.4966           0.4982
# 2          0.5259  +0.0751         0.4923           0.8619
#
#                       Лучший случай (SSIM) Минимум (SSIM)  \
# 0                 drawing_defocus_pink.png         0.2767
# 1  barbara_hookdefocus_kernel_gaussian.png         0.4951
# 2                 drawing_defocus_pink.png         0.2767
#
#                   Худший случай (SSIM) Отн. ошибки  Время (с)
# 0              star_spiral_impulse.png        1.27      40.29
# 1  boy_hookdefocus_kernel_gaussian.png        1.21      29.28
# 2              star_spiral_impulse.png        1.26      39.87
#
# [3 rows x 21 columns]
# Общий CSV: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\PMP\all_results_PMP.csv
