# %% [markdown]
# # Эксперименты и графики для одного алгоритма слепой деконволюции
#
# Ноутбук для прогона конкретного алгоритма на тестовых датасетах и построения индивидуальных графиков.
#
# **Инструкция по использованию:**
# 1. **Ячейка 2 (Настройка)** — задать алгоритм, параметры, пути к папкам
# 2. **Ячейки 3–4 (Датасет)** — настройка датасета + прогон. Копировать эту пару для каждого нового датасета
# 3. **Последняя ячейка** — финальная сводка по всем датасетам для данного алгоритма

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 1. Общая настройка ноутбука: алгоритм, пути, параметры
# ══════════════════════════════════════════════════════════════════════════════
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from pathlib import Path
from typing import Optional, Dict, List, Tuple
import visualisation as vis  # <-- все графики и TeX-генерация


# ── Автоопределение корня проекта ────────────────────────────────────────────
# Работает независимо от того, где лежит ноутбук: ищем pyproject.toml или src/
_nb_dir = Path(os.path.abspath("")).resolve()
PROJECT_ROOT = _nb_dir
for _p in [_nb_dir] + list(_nb_dir.parents):
    if (_p / "pyproject.toml").exists() or (_p / "src").is_dir():
        PROJECT_ROOT = _p
        break

sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / "src"))
os.chdir(PROJECT_ROOT)



# ── Настраиваемые параметры ──────────────────────────────────────────────────
ALGORITHM_LABEL = "Logrifmic image prior - primal dual"   # <-- Менять для каждого алгоритма

# DATASETS_ROOT = PROJECT_ROOT / "validate_images"
DATASETS_ROOT = PROJECT_ROOT / "images" / "compare_data"
RESULTS_ROOT  = PROJECT_ROOT / "presentation_graphics"
RESULTS_ROOT.mkdir(parents=True, exist_ok=True)
ALG_RESULTS_DIR = RESULTS_ROOT / ALGORITHM_LABEL.replace(" ", "_")
ALG_RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# ── Параллелизация ───────────────────────────────────────────────────────────
NUM_WORKERS = 6  # Число параллельных процессов (1 = последовательно)

# --- Алгоритм: модуль / класс / параметры (для параллельного воркера) ---
ALG_MODULE = "src.blinddeconv.algorithms.blind_deconvolution.our_company.logarithmic_pds.lip_denoise.lip"
ALG_CLASS = "LIP_BD"
ALG_KERNEL_PARAM = "kernel_shape"  # имя аргумента размера ядра в конструкторе
ALG_KWARGS = {
    'method': 'pd',
    'lambda_val': 30000.0,
    'tau': 1e-3,
    'outer_iters': 140 // 2,
    'inner_iters': 20,
    'kernel_threshold': 0.18,
    'final_deconv': 'ringing_removal',
    'final_alpha': 0.001,
    'verbose': False,
    'impulse_preprocess': 'auto',
    'noise_estimation': 'pca',
    'screenot_preprocess': 'none',
    'act_preprocess': 'auto',
    'preprocess': 'bilateral',
    'noise_preprocess': 'auto',
    'blind_denoise': 'bilateral',
    'pre_nonblind': 'none',
    'auto_params': None,
}

from src.blinddeconv.algorithms.blind_deconvolution.our_company.logarithmic_pds.lip_denoise.lip import LIP_BD

def create_algorithm(kernel_shape=(31, 31)):
    """Создаёт экземпляр алгоритма (для интерактивного использования)."""
    kw = dict(ALG_KWARGS)
    kw[ALG_KERNEL_PARAM] = kernel_shape
    return LIP_BD(**kw)

# def create_algorithm(kernel_shape=(31, 31)):
#     """Создаёт экземпляр алгоритма (для интерактивного использования)."""
#     alg = 
#     return alg

# ── Утилиты ──────────────────────────────────────────────────────────────────

def parse_distorted_name(filename: str) -> Tuple[Optional[str], Optional[str], Optional[str]]:
    stem = Path(filename).stem
    parts = stem.split("_")
    if len(parts) >= 2:
        return parts[0], parts[1], "_".join(parts[2:]) if len(parts) > 2 else ""
    return stem, None, None

def find_kernel_for_image(kernel_dir: Path, kernel_name: str) -> Optional[Path]:
    if not kernel_dir.exists():
        return None
    for f in kernel_dir.iterdir():
        if f.is_file() and kernel_name in f.stem:
            return f
    return None

def error_ratio_nonblind(original, blurred, true_kernel, est_kernel) -> float:
    """error ratio = MSE(Wiener с est_kernel) / MSE(Wiener с true_kernel)."""
    from numpy.fft import fft2, ifft2
    h, w = blurred.shape[:2]
    reg = 1e-3
    def _wr(y, k):
        K = fft2(k, s=(h, w)); Y = fft2(y, s=(h, w))
        return np.real(ifft2(np.conj(K) * Y / (np.abs(K)**2 + reg)))
    x_true = _wr(blurred, true_kernel)
    x_est  = _wr(blurred, est_kernel)
    orig = original.astype(np.float64)
    mse_true = np.mean((orig - x_true)**2)
    mse_est  = np.mean((orig - x_est)**2)
    return mse_est / mse_true if mse_true > 1e-12 else 1.0

# ── matplotlib настройки ─────────────────────────────────────────────────────
plt.rcParams.update({'font.size': 12, 'figure.dpi': 120,
                     'savefig.dpi': 150, 'savefig.bbox': 'tight'})

ALL_DATASET_RESULTS: List[Dict] = []

print(f"Алгоритм: {ALGORITHM_LABEL}")
print(f"Папка наборов данных: {DATASETS_ROOT}")
print(f"Папка результатов: {ALG_RESULTS_DIR}")
# Out:
# Алгоритм: Logrifmic image prior - primal dual
# Папка наборов данных: D:\for_proga\franework_deconvolution\framework (9)\images\compare_data
# Папка результатов: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2a. Настройка текущего датасета
# ══════════════════════════════════════════════════════════════════════════════
DATASET_NAME = "Levin"   # <-- Менять для другого датасета
DATASET_DIR = DATASETS_ROOT / DATASET_NAME

# Папки датасета
DIST_DIR   = DATASET_DIR / "distorted"
ORIG_DIR   = DATASET_DIR / "originals"
KERNEL_DIR = DATASET_DIR / "ground_truth_filters"

# Проверяем наличие
has_originals = ORIG_DIR.exists() and any(ORIG_DIR.iterdir())
has_kernels   = KERNEL_DIR.exists() and any(KERNEL_DIR.iterdir())
has_distorted = DIST_DIR.exists() and any(DIST_DIR.iterdir())

# Папка для результатов этого датасета
DS_RESULT_DIR = ALG_RESULTS_DIR / DATASET_NAME
DS_RESULT_DIR.mkdir(parents=True, exist_ok=True)
(DS_RESULT_DIR / "restored").mkdir(exist_ok=True)
(DS_RESULT_DIR / "kernels").mkdir(exist_ok=True)

print(f"Датасет: {DATASET_NAME}")
print(f"  Искажённые: {has_distorted}  |  Оригиналы: {has_originals}  |  GT ядра: {has_kernels}")
print(f"  Результаты → {DS_RESULT_DIR}")
# Out:
# Датасет: Levin
#   Искажённые: True  |  Оригиналы: True  |  GT ядра: True
#   Результаты → D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\Levin

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2b. Прогон алгоритма на датасете (параллельно)
# ══════════════════════════════════════════════════════════════════════════════
import importlib
import _process_worker; importlib.reload(_process_worker)
from concurrent.futures import ProcessPoolExecutor, as_completed

distorted_files = sorted([f for f in DIST_DIR.iterdir() if f.is_file()])
print(f"Найдено {len(distorted_files)} искажённых изображений  |  Воркеров: {NUM_WORKERS}\n")

# Формируем задания
tasks = []
for dist_file in distorted_files:
    tasks.append({
        'project_root': str(PROJECT_ROOT),
        'dist_file': str(dist_file),
        'orig_dir': str(ORIG_DIR),
        'kernel_dir': str(KERNEL_DIR),
        'has_originals': has_originals,
        'has_kernels': has_kernels,
        'dataset_name': DATASET_NAME,
        'algorithm_label': ALGORITHM_LABEL,
        'alg_module': ALG_MODULE,
        'alg_class': ALG_CLASS,
        'alg_kwargs': ALG_KWARGS,
        'alg_kernel_param': ALG_KERNEL_PARAM,
        'ds_result_dir': str(DS_RESULT_DIR),
    })

# Параллельный / последовательный запуск
results_rows = []
if NUM_WORKERS > 1:
    with ProcessPoolExecutor(
        max_workers=NUM_WORKERS,
        initializer=_process_worker.init_worker,
        initargs=(str(PROJECT_ROOT),),
    ) as pool:
        futures = {pool.submit(_process_worker.process_one, t): t for t in tasks}
        for future in as_completed(futures):
            r = future.result()
            if r is None:
                fname = Path(futures[future]['dist_file']).name
                print(f"✗ {fname}: не удалось загрузить")
            elif 'error' in r:
                print(f"✗ {r['dist_file']}: {r['error']}")
            else:
                results_rows.append(r)
                psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
                er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
                print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")
else:
    for t in tasks:
        r = _process_worker.process_one(t)
        if r is None:
            print(f"✗ {Path(t['dist_file']).name}: не удалось загрузить")
        elif 'error' in r:
            print(f"✗ {r['dist_file']}: {r['error']}")
        else:
            results_rows.append(r)
            psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
            er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
            print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")

# Сохранение CSV
df_results = pd.DataFrame(results_rows)
csv_path = DS_RESULT_DIR / f"results_{ALGORITHM_LABEL}_{DATASET_NAME}.csv"
df_results.to_csv(csv_path, index=False)
print(f"\n{'─'*60}\nОбработано: {len(results_rows)}/{len(tasks)}  |  CSV: {csv_path}")
display(df_results)

# Запуск генерации красивых картинок 2x4
vis.save_complex_plots(
    df=df_results, 
    dist_dir=DIST_DIR, 
    save_dir=DS_RESULT_DIR / "complex_plots", 
    alg_label=ALGORITHM_LABEL
)

# Добавляем в общий список
ALL_DATASET_RESULTS.append({
    'dataset': DATASET_NAME,
    'df': df_results.copy(),
    'dir': DS_RESULT_DIR,
    'has_originals': has_originals,
    'has_kernels': has_kernels,
})
# Out:
# Найдено 192 искажённых изображений  |  Воркеров: 6
#
# ✓ boy_comet_kernel_clean.png  PSNR=21.40  ER=1.46  t=114.7с
# ✓ boy_comet_kernel_pink.png  PSNR=20.13  ER=1.47  t=115.6с
# ✓ boy_comet_kernel_brown.png  PSNR=20.81  ER=1.18  t=116.4с
# ✓ boy_comet_kernel_impulse.png  PSNR=20.83  ER=3.59  t=116.5с
# ✓ boy_comet_kernel_gaussian.png  PSNR=21.24  ER=1.94  t=117.8с
# ✓ boy_comet_kernel_poisson.png  PSNR=20.51  ER=1.49  t=121.4с
# ✓ boy_defocus_kernel_clean.png  PSNR=28.89  ER=0.58  t=90.1с
# ✓ boy_defocus_kernel_impulse.png  PSNR=29.47  ER=3.19  t=91.2с
# ✓ boy_defocus_kernel_brown.png  PSNR=27.61  ER=0.63  t=93.0с
# ✓ boy_defocus_kernel_gaussian.png  PSNR=27.23  ER=0.97  t=91.4с
# ✓ boy_defocus_kernel_pink.png  PSNR=27.68  ER=0.89  t=92.8с
# ✓ boy_defocus_kernel_poisson.png  PSNR=28.79  ER=0.71  t=93.0с
# ✓ boy_defocusmotion_kernel_brown.png  PSNR=23.80  ER=1.13  t=90.3с
# ✓ boy_defocusmotion_kernel_clean.png  PSNR=24.94  ER=1.09  t=90.5с
# ✓ boy_defocusmotion_kernel_gaussian.png  PSNR=24.56  ER=1.66  t=92.7с
# ✓ boy_defocusmotion_kernel_pink.png  PSNR=23.78  ER=1.47  t=91.6с
# ✓ boy_defocusmotion_kernel_impulse.png  PSNR=25.30  ER=3.71  t=95.1с
# ✓ boy_defocusmotion_kernel_poisson.png  PSNR=24.57  ER=1.33  t=91.8с
# ✓ boy_heliod_kernel_clean.png  PSNR=20.19  ER=0.72  t=102.8с
# ✓ boy_heliod_kernel_brown.png  PSNR=18.83  ER=0.57  t=106.2с
# ✓ boy_heliod_kernel_impulse.png  PSNR=20.45  ER=0.73  t=103.3с
# ✓ boy_heliod_kernel_pink.png  PSNR=19.57  ER=0.76  t=104.5с
# ✓ boy_heliod_kernel_gaussian.png  PSNR=20.27  ER=0.68  t=108.2с
# ✓ boy_heliod_kernel_poisson.png  PSNR=20.16  ER=0.78  t=104.7с
# ✓ boy_hookdefocus_kernel_brown.png  PSNR=18.99  ER=0.82  t=105.0с
# ✓ boy_hookdefocus_kernel_gaussian.png  PSNR=18.67  ER=1.03  t=108.2с
# ✓ boy_hookdefocus_kernel_impulse.png  PSNR=19.60  ER=1.65  t=106.4с
# ✓ boy_hookdefocus_kernel_clean.png  PSNR=18.83  ER=0.81  t=112.1с
# ✓ boy_hookdefocus_kernel_poisson.png  PSNR=19.39  ER=0.98  t=108.0с
# ✓ boy_hookdefocus_kernel_pink.png  PSNR=20.53  ER=1.21  t=111.7с
# ✓ boy_linear_kernel_brown.png  PSNR=24.64  ER=0.81  t=74.8с
# ✓ boy_linear_kernel_clean.png  PSNR=25.76  ER=0.83  t=75.7с
# ✓ boy_linear_kernel_gaussian.png  PSNR=25.70  ER=1.26  t=76.4с
# ✓ boy_linear_kernel_impulse.png  PSNR=25.31  ER=1.35  t=76.6с
# ✓ boy_linear_kernel_pink.png  PSNR=25.35  ER=1.11  t=75.9с
# ✓ boy_linear_kernel_poisson.png  PSNR=25.85  ER=1.18  t=79.0с
# ✓ boy_pacman_kernel_brown.png  PSNR=20.46  ER=1.08  t=86.9с
# ✓ boy_pacman_kernel_clean.png  PSNR=23.46  ER=1.39  t=85.7с
# ✓ boy_pacman_kernel_gaussian.png  PSNR=21.45  ER=1.49  t=86.7с
# ✓ boy_pacman_kernel_impulse.png  PSNR=23.67  ER=1.74  t=86.4с
# ✓ boy_pacman_kernel_pink.png  PSNR=22.06  ER=1.39  t=85.0с
# ✓ boy_pacman_kernel_poisson.png  PSNR=21.14  ER=1.28  t=88.9с
# ✓ boy_wspiral_kernel_brown.png  PSNR=19.12  ER=0.93  t=99.0с
# ✓ boy_wspiral_kernel_clean.png  PSNR=19.17  ER=0.83  t=102.0с
# ✓ boy_wspiral_kernel_gaussian.png  PSNR=19.19  ER=0.86  t=101.8с
# ✓ boy_wspiral_kernel_pink.png  PSNR=19.21  ER=0.87  t=99.9с
# ✓ boy_wspiral_kernel_impulse.png  PSNR=19.09  ER=0.87  t=105.1с
# ✓ boy_wspiral_kernel_poisson.png  PSNR=19.08  ER=0.93  t=112.0с
# ✓ childs_comet_kernel_brown.png  PSNR=15.84  ER=1.58  t=109.3с
# ✓ childs_comet_kernel_impulse.png  PSNR=16.17  ER=2.40  t=111.5с
# ✓ childs_comet_kernel_clean.png  PSNR=16.17  ER=1.64  t=114.1с
# ✓ childs_comet_kernel_gaussian.png  PSNR=16.09  ER=1.77  t=113.1с
# ✓ childs_comet_kernel_pink.png  PSNR=17.65  ER=1.48  t=112.5с
# ✓ childs_comet_kernel_poisson.png  PSNR=16.84  ER=1.47  t=118.6с
# ✓ childs_defocus_kernel_brown.png  PSNR=26.12  ER=0.73  t=85.0с
# ✓ childs_defocus_kernel_gaussian.png  PSNR=27.26  ER=1.01  t=88.6с
# ✓ childs_defocus_kernel_impulse.png  PSNR=27.57  ER=2.93  t=88.0с
# ✓ childs_defocus_kernel_clean.png  PSNR=28.22  ER=0.64  t=89.3с
# ✓ childs_defocus_kernel_pink.png  PSNR=27.23  ER=0.86  t=88.5с
# ✓ childs_defocus_kernel_poisson.png  PSNR=27.64  ER=0.76  t=91.5с
# ✓ childs_defocusmotion_kernel_brown.png  PSNR=24.02  ER=1.05  t=86.2с
# ✓ childs_defocusmotion_kernel_gaussian.png  PSNR=24.55  ER=1.47  t=87.9с
# ✓ childs_defocusmotion_kernel_impulse.png  PSNR=24.54  ER=3.29  t=87.8с
# ✓ childs_defocusmotion_kernel_clean.png  PSNR=24.53  ER=1.02  t=89.5с
# ✓ childs_defocusmotion_kernel_pink.png  PSNR=23.81  ER=1.28  t=88.1с
# ✓ childs_defocusmotion_kernel_poisson.png  PSNR=24.67  ER=1.20  t=90.4с
# ✓ childs_heliod_kernel_brown.png  PSNR=18.45  ER=0.70  t=98.3с
# ✓ childs_heliod_kernel_clean.png  PSNR=19.10  ER=0.64  t=100.6с
# ✓ childs_heliod_kernel_impulse.png  PSNR=18.37  ER=0.81  t=101.5с
# ✓ childs_heliod_kernel_gaussian.png  PSNR=18.94  ER=0.71  t=103.7с
# ✓ childs_heliod_kernel_pink.png  PSNR=19.02  ER=0.70  t=101.6с
# ✓ childs_heliod_kernel_poisson.png  PSNR=18.46  ER=0.67  t=106.6с
# ✓ childs_hookdefocus_kernel_brown.png  PSNR=17.88  ER=0.78  t=102.0с
# ✓ childs_hookdefocus_kernel_clean.png  PSNR=17.48  ER=0.74  t=105.2с
# ✓ childs_hookdefocus_kernel_impulse.png  PSNR=17.73  ER=1.63  t=104.5с
# ✓ childs_hookdefocus_kernel_gaussian.png  PSNR=17.73  ER=1.00  t=105.9с
# ✓ childs_hookdefocus_kernel_pink.png  PSNR=18.26  ER=0.92  t=108.7с
# ✓ childs_hookdefocus_kernel_poisson.png  PSNR=17.77  ER=0.92  t=114.0с
# ✓ childs_linear_kernel_brown.png  PSNR=23.79  ER=0.77  t=75.2с
# ✓ childs_linear_kernel_clean.png  PSNR=26.29  ER=1.06  t=75.4с
# ✓ childs_linear_kernel_gaussian.png  PSNR=24.81  ER=1.15  t=76.3с
# ✓ childs_linear_kernel_impulse.png  PSNR=26.16  ER=1.38  t=76.8с
# ✓ childs_linear_kernel_pink.png  PSNR=24.62  ER=1.09  t=75.1с
# ✓ childs_linear_kernel_poisson.png  PSNR=25.22  ER=1.08  t=79.7с
# ✓ childs_pacman_kernel_brown.png  PSNR=20.75  ER=1.05  t=84.7с
# ✓ childs_pacman_kernel_clean.png  PSNR=19.39  ER=1.12  t=84.1с
# ✓ childs_pacman_kernel_gaussian.png  PSNR=20.38  ER=1.42  t=84.7с
# ✓ childs_pacman_kernel_impulse.png  PSNR=21.77  ER=1.82  t=85.1с
# ✓ childs_pacman_kernel_pink.png  PSNR=20.72  ER=1.18  t=84.8с
# ✓ childs_pacman_kernel_poisson.png  PSNR=21.35  ER=1.30  t=86.9с
# ✓ childs_wspiral_kernel_brown.png  PSNR=17.06  ER=0.77  t=97.8с
# ✓ childs_wspiral_kernel_clean.png  PSNR=20.62  ER=1.07  t=98.2с
# ✓ childs_wspiral_kernel_impulse.png  PSNR=20.70  ER=0.90  t=99.4с
# ✓ childs_wspiral_kernel_gaussian.png  PSNR=17.39  ER=0.82  t=100.7с
# ✓ childs_wspiral_kernel_pink.png  PSNR=17.29  ER=0.82  t=100.0с
# ✓ childs_wspiral_kernel_poisson.png  PSNR=20.76  ER=1.07  t=106.3с
# ✓ drawing_comet_kernel_brown.png  PSNR=18.42  ER=1.08  t=107.5с
# ✓ drawing_comet_kernel_clean.png  PSNR=18.40  ER=1.16  t=110.8с
# ✓ drawing_comet_kernel_gaussian.png  PSNR=18.33  ER=1.76  t=111.7с
# ✓ drawing_comet_kernel_impulse.png  PSNR=18.27  ER=4.30  t=112.2с
# ✓ drawing_comet_kernel_pink.png  PSNR=18.52  ER=1.58  t=111.1с
# ✓ drawing_defocus_kernel_brown.png  PSNR=26.89  ER=0.54  t=87.7с
# ✓ drawing_comet_kernel_poisson.png  PSNR=18.41  ER=1.40  t=120.1с
# ✓ drawing_defocus_kernel_clean.png  PSNR=29.17  ER=0.47  t=86.9с
# ✓ drawing_defocus_kernel_gaussian.png  PSNR=27.02  ER=0.82  t=87.2с
# ✓ drawing_defocus_kernel_impulse.png  PSNR=28.48  ER=2.64  t=87.8с
# ✓ drawing_defocus_kernel_pink.png  PSNR=26.17  ER=0.71  t=87.5с
# ✓ drawing_defocus_kernel_poisson.png  PSNR=28.34  ER=0.62  t=90.3с
# ✓ drawing_defocusmotion_kernel_brown.png  PSNR=23.65  ER=1.10  t=88.0с
# ✓ drawing_defocusmotion_kernel_clean.png  PSNR=24.55  ER=1.07  t=87.5с
# ✓ drawing_defocusmotion_kernel_gaussian.png  PSNR=24.18  ER=1.72  t=87.8с
# ✓ drawing_defocusmotion_kernel_impulse.png  PSNR=24.83  ER=3.43  t=88.4с
# ✓ drawing_defocusmotion_kernel_pink.png  PSNR=23.62  ER=1.44  t=87.7с
# ✓ drawing_defocusmotion_kernel_poisson.png  PSNR=24.50  ER=1.23  t=90.8с
# ✓ drawing_heliod_kernel_brown.png  PSNR=18.73  ER=0.88  t=99.2с
# ✓ drawing_heliod_kernel_clean.png  PSNR=19.54  ER=0.97  t=97.9с
# ✓ drawing_heliod_kernel_gaussian.png  PSNR=19.60  ER=0.79  t=100.8с
# ✓ drawing_heliod_kernel_impulse.png  PSNR=19.25  ER=0.63  t=100.5с
# ✓ drawing_heliod_kernel_pink.png  PSNR=18.61  ER=0.82  t=100.1с
# ✓ drawing_heliod_kernel_poisson.png  PSNR=19.46  ER=0.89  t=102.1с
# ✓ drawing_hookdefocus_kernel_brown.png  PSNR=18.49  ER=0.94  t=107.2с
# ✓ drawing_hookdefocus_kernel_clean.png  PSNR=19.09  ER=0.92  t=103.4с
# ✓ drawing_hookdefocus_kernel_impulse.png  PSNR=19.18  ER=1.69  t=104.4с
# ✓ drawing_hookdefocus_kernel_gaussian.png  PSNR=19.19  ER=1.19  t=106.0с
# ✓ drawing_hookdefocus_kernel_pink.png  PSNR=18.73  ER=1.11  t=108.8с
# ✓ drawing_linear_kernel_brown.png  PSNR=24.76  ER=1.03  t=75.0с
# ✓ drawing_hookdefocus_kernel_poisson.png  PSNR=18.51  ER=1.06  t=109.6с
# ✓ drawing_linear_kernel_clean.png  PSNR=26.23  ER=1.05  t=76.1с
# ✓ drawing_linear_kernel_impulse.png  PSNR=26.21  ER=1.25  t=74.4с
# ✓ drawing_linear_kernel_gaussian.png  PSNR=24.12  ER=1.04  t=76.1с
# ✓ drawing_linear_kernel_pink.png  PSNR=24.57  ER=1.04  t=75.0с
# ✓ drawing_linear_kernel_poisson.png  PSNR=25.65  ER=1.10  t=80.2с
# ✓ drawing_pacman_kernel_brown.png  PSNR=20.18  ER=1.17  t=85.3с
# ✓ drawing_pacman_kernel_clean.png  PSNR=20.00  ER=1.15  t=86.0с
# ✓ drawing_pacman_kernel_gaussian.png  PSNR=20.69  ER=1.44  t=85.6с
# ✓ drawing_pacman_kernel_impulse.png  PSNR=19.91  ER=1.69  t=87.6с
# ✓ drawing_pacman_kernel_pink.png  PSNR=19.32  ER=1.26  t=85.3с
# ✓ drawing_pacman_kernel_poisson.png  PSNR=19.67  ER=1.28  t=85.4с
# ✓ drawing_wspiral_kernel_brown.png  PSNR=17.60  ER=0.82  t=97.0с
# ✓ drawing_wspiral_kernel_clean.png  PSNR=17.79  ER=0.81  t=96.2с
# ✓ drawing_wspiral_kernel_gaussian.png  PSNR=18.00  ER=0.84  t=98.6с
# ✓ drawing_wspiral_kernel_impulse.png  PSNR=20.90  ER=0.95  t=99.2с
# ✓ drawing_wspiral_kernel_pink.png  PSNR=17.90  ER=0.93  t=102.0с
# ✓ drawing_wspiral_kernel_poisson.png  PSNR=17.75  ER=0.85  t=104.0с
# ✓ house_comet_kernel_brown.png  PSNR=19.03  ER=1.11  t=106.3с
# ✓ house_comet_kernel_clean.png  PSNR=18.91  ER=1.13  t=110.1с
# ✓ house_comet_kernel_gaussian.png  PSNR=19.08  ER=1.78  t=110.5с
# ✓ house_comet_kernel_impulse.png  PSNR=18.81  ER=4.73  t=110.6с
# ✓ house_comet_kernel_pink.png  PSNR=18.94  ER=1.59  t=112.0с
# ✓ house_defocus_kernel_brown.png  PSNR=25.27  ER=0.57  t=86.3с
# ✓ house_comet_kernel_poisson.png  PSNR=18.91  ER=1.37  t=115.4с
# ✓ house_defocus_kernel_clean.png  PSNR=25.93  ER=0.46  t=88.2с
# ✓ house_defocus_kernel_gaussian.png  PSNR=25.01  ER=0.97  t=87.3с
# ✓ house_defocus_kernel_impulse.png  PSNR=25.83  ER=3.43  t=87.5с
# ✓ house_defocus_kernel_pink.png  PSNR=24.79  ER=0.82  t=87.7с
# ✓ house_defocusmotion_kernel_brown.png  PSNR=22.79  ER=1.08  t=87.2с
# ✓ house_defocus_kernel_poisson.png  PSNR=25.65  ER=0.62  t=92.8с
# ✓ house_defocusmotion_kernel_clean.png  PSNR=23.43  ER=1.08  t=88.3с
# ✓ house_defocusmotion_kernel_gaussian.png  PSNR=22.93  ER=1.78  t=88.9с
# ✓ house_defocusmotion_kernel_impulse.png  PSNR=23.33  ER=4.64  t=88.3с
# ✓ house_defocusmotion_kernel_pink.png  PSNR=22.71  ER=1.55  t=88.0с
# ✓ house_defocusmotion_kernel_poisson.png  PSNR=23.08  ER=1.28  t=91.4с
# ✓ house_heliod_kernel_brown.png  PSNR=18.71  ER=0.83  t=102.4с
# ✓ house_heliod_kernel_clean.png  PSNR=19.57  ER=0.88  t=100.7с
# ✓ house_heliod_kernel_gaussian.png  PSNR=19.15  ER=0.85  t=104.4с
# ✓ house_heliod_kernel_impulse.png  PSNR=19.40  ER=0.73  t=103.4с
# ✓ house_heliod_kernel_pink.png  PSNR=18.86  ER=0.83  t=106.7с
# ✓ house_heliod_kernel_poisson.png  PSNR=19.20  ER=0.90  t=107.5с
# ✓ house_hookdefocus_kernel_brown.png  PSNR=18.34  ER=0.88  t=106.5с
# ✓ house_hookdefocus_kernel_clean.png  PSNR=18.31  ER=0.89  t=107.8с
# ✓ house_hookdefocus_kernel_gaussian.png  PSNR=18.35  ER=1.28  t=107.4с
# ✓ house_hookdefocus_kernel_impulse.png  PSNR=18.47  ER=1.91  t=105.6с
# ✓ house_hookdefocus_kernel_pink.png  PSNR=19.41  ER=1.10  t=110.6с
# ✓ house_linear_kernel_brown.png  PSNR=24.00  ER=0.94  t=75.5с
# ✓ house_linear_kernel_clean.png  PSNR=24.97  ER=1.00  t=76.8с
# ✓ house_hookdefocus_kernel_poisson.png  PSNR=18.23  ER=0.99  t=110.3с
# ✓ house_linear_kernel_gaussian.png  PSNR=23.47  ER=1.15  t=77.1с
# ✓ house_linear_kernel_impulse.png  PSNR=24.91  ER=1.33  t=77.0с
# ✓ house_linear_kernel_pink.png  PSNR=23.88  ER=1.13  t=76.2с
# ✓ house_linear_kernel_poisson.png  PSNR=24.36  ER=1.13  t=81.1с
# ✓ house_pacman_kernel_brown.png  PSNR=18.95  ER=0.88  t=86.8с
# ✓ house_pacman_kernel_clean.png  PSNR=19.33  ER=0.93  t=87.2с
# ✓ house_pacman_kernel_gaussian.png  PSNR=19.59  ER=1.48  t=86.5с
# ✓ house_pacman_kernel_impulse.png  PSNR=21.11  ER=1.98  t=86.6с
# ✓ house_pacman_kernel_pink.png  PSNR=19.84  ER=1.30  t=85.2с
# ✓ house_pacman_kernel_poisson.png  PSNR=19.09  ER=1.07  t=88.2с
# ✓ house_wspiral_kernel_brown.png  PSNR=17.75  ER=1.00  t=97.8с
# ✓ house_wspiral_kernel_gaussian.png  PSNR=19.43  ER=0.96  t=99.0с
# ✓ house_wspiral_kernel_impulse.png  PSNR=17.82  ER=0.95  t=98.2с
# ✓ house_wspiral_kernel_clean.png  PSNR=18.14  ER=1.04  t=100.6с
# ✓ house_wspiral_kernel_pink.png  PSNR=17.65  ER=1.04  t=94.3с
# ✓ house_wspiral_kernel_poisson.png  PSNR=18.24  ER=1.01  t=70.3с
#
# ────────────────────────────────────────────────────────────
# Обработано: 192/192  |  CSV: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\Levin\results_Logrifmic image prior - primal dual_Levin.csv
#     dataset                     distorted_file image_name kernel_name  \
# 0     Levin         boy_comet_kernel_clean.png        boy       comet
# 1     Levin          boy_comet_kernel_pink.png        boy       comet
# 2     Levin         boy_comet_kernel_brown.png        boy       comet
# 3     Levin       boy_comet_kernel_impulse.png        boy       comet
# 4     Levin      boy_comet_kernel_gaussian.png        boy       comet
# ..      ...                                ...        ...         ...
# 187   Levin  house_wspiral_kernel_gaussian.png      house     wspiral
# 188   Levin   house_wspiral_kernel_impulse.png      house     wspiral
# 189   Levin     house_wspiral_kernel_clean.png      house     wspiral
# 190   Levin      house_wspiral_kernel_pink.png      house     wspiral
# 191   Levin   house_wspiral_kernel_poisson.png      house     wspiral
#
#           noise_name kernel_shape  time_sec  \
# 0       kernel_clean     (35, 35)   114.697
# 1        kernel_pink     (35, 35)   115.601
# 2       kernel_brown     (35, 35)   116.413
# 3     kernel_impulse     (35, 35)   116.475
# 4    kernel_gaussian     (35, 35)   117.801
# ..               ...          ...       ...
# 187  kernel_gaussian     (31, 31)    99.049
# 188   kernel_impulse     (31, 31)    98.159
# 189     kernel_clean     (31, 31)   100.623
# 190      kernel_pink     (31, 31)    94.307
# 191   kernel_poisson     (31, 31)    70.262
#
#                                          restored_path  \
# 0    D:\for_proga\franework_deconvolution\framework...
# 1    D:\for_proga\franework_deconvolution\framework...
# 2    D:\for_proga\franework_deconvolution\framework...
# 3    D:\for_proga\franework_deconvolution\framework...
# 4    D:\for_proga\franework_deconvolution\framework...
# ..                                                 ...
# 187  D:\for_proga\franework_deconvolution\framework...
# 188  D:\for_proga\franework_deconvolution\framework...
# 189  D:\for_proga\franework_deconvolution\framework...
# 190  D:\for_proga\franework_deconvolution\framework...
# 191  D:\for_proga\franework_deconvolution\framework...
#
#                                            kernel_path  \
# 0    D:\for_proga\franework_deconvolution\framework...
# 1    D:\for_proga\franework_deconvolution\framework...
# 2    D:\for_proga\franework_deconvolution\framework...
# 3    D:\for_proga\franework_deconvolution\framework...
# 4    D:\for_proga\franework_deconvolution\framework...
# ..                                                 ...
# 187  D:\for_proga\franework_deconvolution\framework...
# 188  D:\for_proga\franework_deconvolution\framework...
# 189  D:\for_proga\franework_deconvolution\framework...
# 190  D:\for_proga\franework_deconvolution\framework...
# 191  D:\for_proga\franework_deconvolution\framework...
#
#                                         gt_kernel_path  \
# 0    D:\for_proga\franework_deconvolution\framework...
# 1    D:\for_proga\franework_deconvolution\framework...
# 2    D:\for_proga\franework_deconvolution\framework...
# 3    D:\for_proga\franework_deconvolution\framework...
# 4    D:\for_proga\franework_deconvolution\framework...
# ..                                                 ...
# 187  D:\for_proga\franework_deconvolution\framework...
# 188  D:\for_proga\franework_deconvolution\framework...
# 189  D:\for_proga\franework_deconvolution\framework...
# 190  D:\for_proga\franework_deconvolution\framework...
# 191  D:\for_proga\franework_deconvolution\framework...
#
#                                          original_path     psnr    ssim  \
# 0    D:\for_proga\franework_deconvolution\framework...  21.4044  0.5632
# 1    D:\for_proga\franework_deconvolution\framework...  20.1317  0.4738
# 2    D:\for_proga\franework_deconvolution\framework...  20.8081  0.4817
# 3    D:\for_proga\franework_deconvolution\framework...  20.8254  0.5417
# 4    D:\for_proga\franework_deconvolution\framework...  21.2414  0.5503
# ..                                                 ...      ...     ...
# 187  D:\for_proga\franework_deconvolution\framework...  19.4314  0.4010
# 188  D:\for_proga\franework_deconvolution\framework...  17.8245  0.2665
# 189  D:\for_proga\franework_deconvolution\framework...  18.1355  0.3012
# 190  D:\for_proga\franework_deconvolution\framework...  17.6469  0.2439
# 191  D:\for_proga\franework_deconvolution\framework...  18.2362  0.3060
#
#      psnr_blurred  ssim_blurred  error_ratio
# 0         21.2032        0.5832       1.4587
# 1         20.9749        0.5054       1.4678
# 2         21.0010        0.5391       1.1799
# 3         19.7568        0.4621       3.5937
# 4         20.9801        0.4998       1.9387
# ..            ...           ...          ...
# 187       18.6048        0.3144       0.9574
# 188       17.6785        0.3040       0.9458
# 189       18.7290        0.3811       1.0351
# 190       18.5867        0.3157       1.0386
# 191       18.6996        0.3701       1.0101
#
# [192 rows x 16 columns]
#   Генерация комплексных изображений (192 шт.). Пожалуйста, подождите...
#   Готово! Сохранено 192 изображений в: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\Levin\complex_plots

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2a. Настройка текущего датасета
# ══════════════════════════════════════════════════════════════════════════════
DATASET_NAME = "Set12"   # <-- Менять для другого датасета
DATASET_DIR = DATASETS_ROOT / DATASET_NAME

# Папки датасета
DIST_DIR   = DATASET_DIR / "distorted"
ORIG_DIR   = DATASET_DIR / "originals"
KERNEL_DIR = DATASET_DIR / "ground_truth_filters"

# Проверяем наличие
has_originals = ORIG_DIR.exists() and any(ORIG_DIR.iterdir())
has_kernels   = KERNEL_DIR.exists() and any(KERNEL_DIR.iterdir())
has_distorted = DIST_DIR.exists() and any(DIST_DIR.iterdir())

# Папка для результатов этого датасета
DS_RESULT_DIR = ALG_RESULTS_DIR / DATASET_NAME
DS_RESULT_DIR.mkdir(parents=True, exist_ok=True)
(DS_RESULT_DIR / "restored").mkdir(exist_ok=True)
(DS_RESULT_DIR / "kernels").mkdir(exist_ok=True)

print(f"Датасет: {DATASET_NAME}")
print(f"  Искажённые: {has_distorted}  |  Оригиналы: {has_originals}  |  GT ядра: {has_kernels}")
print(f"  Результаты → {DS_RESULT_DIR}")
# Out:
# Датасет: Set12
#   Искажённые: True  |  Оригиналы: True  |  GT ядра: True
#   Результаты → D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\Set12

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 2b. Прогон алгоритма на датасете (параллельно)
# ══════════════════════════════════════════════════════════════════════════════
import importlib
import _process_worker; importlib.reload(_process_worker)
from concurrent.futures import ProcessPoolExecutor, as_completed

distorted_files = sorted([f for f in DIST_DIR.iterdir() if f.is_file()])
print(f"Найдено {len(distorted_files)} искажённых изображений  |  Воркеров: {NUM_WORKERS}\n")

# Формируем задания
tasks = []
for dist_file in distorted_files:
    tasks.append({
        'project_root': str(PROJECT_ROOT),
        'dist_file': str(dist_file),
        'orig_dir': str(ORIG_DIR),
        'kernel_dir': str(KERNEL_DIR),
        'has_originals': has_originals,
        'has_kernels': has_kernels,
        'dataset_name': DATASET_NAME,
        'algorithm_label': ALGORITHM_LABEL,
        'alg_module': ALG_MODULE,
        'alg_class': ALG_CLASS,
        'alg_kwargs': ALG_KWARGS,
        'alg_kernel_param': ALG_KERNEL_PARAM,
        'ds_result_dir': str(DS_RESULT_DIR),
    })

# Параллельный / последовательный запуск
results_rows = []
if NUM_WORKERS > 1:
    with ProcessPoolExecutor(
        max_workers=NUM_WORKERS,
        initializer=_process_worker.init_worker,
        initargs=(str(PROJECT_ROOT),),
    ) as pool:
        futures = {pool.submit(_process_worker.process_one, t): t for t in tasks}
        for future in as_completed(futures):
            r = future.result()
            if r is None:
                fname = Path(futures[future]['dist_file']).name
                print(f"✗ {fname}: не удалось загрузить")
            elif 'error' in r:
                print(f"✗ {r['dist_file']}: {r['error']}")
            else:
                results_rows.append(r)
                psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
                er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
                print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")
else:
    for t in tasks:
        r = _process_worker.process_one(t)
        if r is None:
            print(f"✗ {Path(t['dist_file']).name}: не удалось загрузить")
        elif 'error' in r:
            print(f"✗ {r['dist_file']}: {r['error']}")
        else:
            results_rows.append(r)
            psnr_s = f"PSNR={r['psnr']:.2f}" if not math.isnan(r.get('psnr', math.nan)) else "no orig"
            er_s = f"{r['error_ratio']:.2f}" if not math.isnan(r.get('error_ratio', math.nan)) else "—"
            print(f"✓ {r['distorted_file']}  {psnr_s}  ER={er_s}  t={r['time_sec']:.1f}с")

# Сохранение CSV
df_results = pd.DataFrame(results_rows)
csv_path = DS_RESULT_DIR / f"results_{ALGORITHM_LABEL}_{DATASET_NAME}.csv"
df_results.to_csv(csv_path, index=False)
print(f"\n{'─'*60}\nОбработано: {len(results_rows)}/{len(tasks)}  |  CSV: {csv_path}")
display(df_results)

# Запуск генерации красивых картинок 2x4
vis.save_complex_plots(
    df=df_results, 
    dist_dir=DIST_DIR, 
    save_dir=DS_RESULT_DIR / "complex_plots", 
    alg_label=ALGORITHM_LABEL
)

# Добавляем в общий список
ALL_DATASET_RESULTS.append({
    'dataset': DATASET_NAME,
    'df': df_results.copy(),
    'dir': DS_RESULT_DIR,
    'has_originals': has_originals,
    'has_kernels': has_kernels,
})
# Out:
# Найдено 192 искажённых изображений  |  Воркеров: 6
#
# ✓ barbara_comet_kernel_brown.png  PSNR=19.22  ER=1.18  t=928.1с
# ✓ barbara_comet_kernel_pink.png  PSNR=19.73  ER=1.46  t=931.5с
# ✓ barbara_comet_kernel_impulse.png  PSNR=19.39  ER=1.89  t=932.5с
# ✓ barbara_comet_kernel_clean.png  PSNR=19.34  ER=1.23  t=934.9с
# ✓ barbara_comet_kernel_gaussian.png  PSNR=19.36  ER=1.61  t=936.6с
# ✓ barbara_comet_kernel_poisson.png  PSNR=19.21  ER=1.42  t=946.4с
# ✓ barbara_defocus_kernel_brown.png  PSNR=22.94  ER=0.85  t=710.4с
# ✓ barbara_defocus_kernel_gaussian.png  PSNR=23.26  ER=1.36  t=708.2с
# ✓ barbara_defocus_kernel_impulse.png  PSNR=23.44  ER=1.83  t=712.1с
# ✓ barbara_defocus_kernel_clean.png  PSNR=23.43  ER=0.74  t=715.8с
# ✓ barbara_defocus_kernel_pink.png  PSNR=23.16  ER=1.14  t=711.1с
# ✓ barbara_defocus_kernel_poisson.png  PSNR=23.19  ER=1.15  t=851.4с
# ✓ barbara_defocusmotion_kernel_brown.png  PSNR=22.32  ER=1.08  t=679.7с
# ✓ barbara_defocusmotion_kernel_clean.png  PSNR=22.78  ER=1.04  t=685.9с
# ✓ barbara_defocusmotion_kernel_pink.png  PSNR=22.57  ER=1.52  t=683.2с
# ✓ barbara_defocusmotion_kernel_gaussian.png  PSNR=22.66  ER=1.70  t=684.0с
# ✓ barbara_defocusmotion_kernel_impulse.png  PSNR=22.88  ER=2.04  t=687.9с
# ✓ barbara_defocusmotion_kernel_poisson.png  PSNR=22.70  ER=1.43  t=707.7с
# ✓ barbara_heliod_kernel_brown.png  PSNR=19.18  ER=0.69  t=826.1с
# ✓ barbara_heliod_kernel_clean.png  PSNR=19.25  ER=0.78  t=828.8с
# ✓ barbara_heliod_kernel_impulse.png  PSNR=19.30  ER=0.77  t=829.8с
# ✓ barbara_heliod_kernel_pink.png  PSNR=19.40  ER=0.76  t=828.1с
# ✓ barbara_heliod_kernel_gaussian.png  PSNR=19.18  ER=0.71  t=834.7с
# ✓ barbara_heliod_kernel_poisson.png  PSNR=19.34  ER=0.75  t=996.8с
# ✓ barbara_hookdefocus_kernel_brown.png  PSNR=19.61  ER=0.97  t=843.7с
# ✓ barbara_hookdefocus_kernel_clean.png  PSNR=20.13  ER=0.94  t=846.5с
# ✓ barbara_hookdefocus_kernel_gaussian.png  PSNR=20.00  ER=1.19  t=847.0с
# ✓ barbara_hookdefocus_kernel_pink.png  PSNR=19.67  ER=1.13  t=845.4с
# ✓ barbara_hookdefocus_kernel_impulse.png  PSNR=20.06  ER=1.41  t=848.2с
# ✓ barbara_hookdefocus_kernel_poisson.png  PSNR=19.99  ER=1.15  t=840.4с
# ✓ barbara_linear_kernel_brown.png  PSNR=22.13  ER=0.87  t=611.0с
# ✓ barbara_linear_kernel_clean.png  PSNR=22.85  ER=0.96  t=619.2с
# ✓ barbara_linear_kernel_pink.png  PSNR=22.15  ER=1.08  t=615.5с
# ✓ barbara_linear_kernel_impulse.png  PSNR=22.88  ER=1.27  t=618.4с
# ✓ barbara_linear_kernel_gaussian.png  PSNR=22.30  ER=1.25  t=622.9с
# ✓ barbara_linear_kernel_poisson.png  PSNR=22.37  ER=1.18  t=607.2с
# ✓ barbara_pacman_kernel_brown.png  PSNR=21.06  ER=1.31  t=712.1с
# ✓ barbara_pacman_kernel_clean.png  PSNR=21.43  ER=1.25  t=714.4с
# ✓ barbara_pacman_kernel_gaussian.png  PSNR=20.33  ER=1.60  t=711.9с
# ✓ barbara_pacman_kernel_impulse.png  PSNR=20.28  ER=1.47  t=713.5с
# ✓ barbara_pacman_kernel_pink.png  PSNR=20.95  ER=1.47  t=717.5с
# ✓ barbara_pacman_kernel_poisson.png  PSNR=20.75  ER=1.53  t=848.2с
# ✓ barbara_wspiral_kernel_brown.png  PSNR=18.79  ER=0.96  t=794.9с
# ✓ barbara_wspiral_kernel_clean.png  PSNR=19.06  ER=0.96  t=796.4с
# ✓ barbara_wspiral_kernel_gaussian.png  PSNR=19.24  ER=0.84  t=797.4с
# ✓ barbara_wspiral_kernel_impulse.png  PSNR=18.86  ER=0.89  t=797.9с
# ✓ barbara_wspiral_kernel_pink.png  PSNR=19.89  ER=0.96  t=795.7с
# ✓ barbara_wspiral_kernel_poisson.png  PSNR=19.97  ER=0.91  t=801.5с
# ✓ boat_comet_kernel_brown.png  PSNR=20.10  ER=1.21  t=831.6с
# ✓ boat_comet_kernel_clean.png  PSNR=19.99  ER=1.19  t=837.6с
# ✓ boat_comet_kernel_gaussian.png  PSNR=20.35  ER=2.01  t=839.2с
# ✓ boat_comet_kernel_pink.png  PSNR=20.17  ER=1.79  t=836.0с
# ✓ boat_comet_kernel_impulse.png  PSNR=19.92  ER=2.61  t=839.9с
# ✓ boat_comet_kernel_poisson.png  PSNR=20.02  ER=1.76  t=822.3с
# ✓ boat_defocus_kernel_brown.png  PSNR=25.24  ER=0.61  t=681.2с
# ✓ boat_defocus_kernel_clean.png  PSNR=26.22  ER=0.52  t=686.3с
# ✓ boat_defocus_kernel_gaussian.png  PSNR=25.57  ER=1.14  t=683.5с
# ✓ boat_defocus_kernel_pink.png  PSNR=25.23  ER=0.99  t=684.2с
# ✓ boat_defocus_kernel_impulse.png  PSNR=26.17  ER=1.49  t=685.1с
# ✓ boat_defocus_kernel_poisson.png  PSNR=25.64  ER=0.92  t=822.2с
# ✓ boat_defocusmotion_kernel_brown.png  PSNR=23.27  ER=1.08  t=664.7с
# ✓ boat_defocusmotion_kernel_gaussian.png  PSNR=23.53  ER=1.86  t=680.1с
# ✓ boat_defocusmotion_kernel_clean.png  PSNR=23.91  ER=1.00  t=683.4с
# ✓ boat_defocusmotion_kernel_pink.png  PSNR=23.42  ER=1.66  t=676.9с
# ✓ boat_defocusmotion_kernel_impulse.png  PSNR=23.98  ER=2.17  t=682.6с
# ✓ boat_defocusmotion_kernel_poisson.png  PSNR=23.77  ER=1.63  t=856.4с
# ✓ boat_heliod_kernel_brown.png  PSNR=19.61  ER=0.70  t=818.9с
# ✓ boat_heliod_kernel_clean.png  PSNR=20.48  ER=0.86  t=818.7с
# ✓ boat_heliod_kernel_gaussian.png  PSNR=20.36  ER=0.70  t=819.0с
# ✓ boat_heliod_kernel_impulse.png  PSNR=20.35  ER=0.70  t=817.4с
# ✓ boat_heliod_kernel_pink.png  PSNR=20.04  ER=0.80  t=815.6с
# ✓ boat_heliod_kernel_poisson.png  PSNR=20.01  ER=0.81  t=782.2с
# ✓ boat_hookdefocus_kernel_brown.png  PSNR=19.80  ER=0.88  t=812.2с
# ✓ boat_hookdefocus_kernel_gaussian.png  PSNR=20.40  ER=1.19  t=815.0с
# ✓ boat_hookdefocus_kernel_impulse.png  PSNR=20.28  ER=1.49  t=814.3с
# ✓ boat_hookdefocus_kernel_clean.png  PSNR=20.21  ER=0.89  t=819.2с
# ✓ boat_hookdefocus_kernel_pink.png  PSNR=20.01  ER=1.17  t=814.6с
# ✓ boat_linear_kernel_brown.png  PSNR=22.61  ER=0.87  t=583.8с
# ✓ boat_linear_kernel_gaussian.png  PSNR=22.81  ER=1.32  t=583.5с
# ✓ boat_linear_kernel_clean.png  PSNR=23.71  ER=0.87  t=590.6с
# ✓ boat_linear_kernel_pink.png  PSNR=22.75  ER=1.12  t=586.5с
# ✓ boat_linear_kernel_impulse.png  PSNR=23.71  ER=1.31  t=591.1с
# ✓ boat_hookdefocus_kernel_poisson.png  PSNR=19.74  ER=1.19  t=802.3с
# ✓ boat_linear_kernel_poisson.png  PSNR=23.30  ER=1.24  t=715.5с
# ✓ boat_pacman_kernel_brown.png  PSNR=20.26  ER=1.38  t=663.5с
# ✓ boat_pacman_kernel_gaussian.png  PSNR=21.76  ER=1.68  t=664.0с
# ✓ boat_pacman_kernel_impulse.png  PSNR=21.77  ER=1.86  t=665.2с
# ✓ boat_pacman_kernel_clean.png  PSNR=20.71  ER=1.43  t=669.2с
# ✓ boat_pacman_kernel_pink.png  PSNR=22.17  ER=1.63  t=656.5с
# ✓ boat_pacman_kernel_poisson.png  PSNR=21.65  ER=1.48  t=680.2с
# ✓ boat_wspiral_kernel_brown.png  PSNR=20.02  ER=1.05  t=760.7с
# ✓ boat_wspiral_kernel_clean.png  PSNR=20.20  ER=1.02  t=760.0с
# ✓ boat_wspiral_kernel_gaussian.png  PSNR=20.19  ER=0.80  t=758.4с
# ✓ boat_wspiral_kernel_impulse.png  PSNR=20.21  ER=0.92  t=759.5с
# ✓ boat_wspiral_kernel_pink.png  PSNR=19.67  ER=0.99  t=754.5с
# ✓ boat_wspiral_kernel_poisson.png  PSNR=20.23  ER=0.90  t=760.4с
# ✓ lena_comet_kernel_brown.png  PSNR=20.63  ER=1.28  t=811.5с
# ✓ lena_comet_kernel_gaussian.png  PSNR=21.15  ER=1.72  t=818.8с
# ✓ lena_comet_kernel_clean.png  PSNR=20.73  ER=1.24  t=822.2с
# ✓ lena_comet_kernel_impulse.png  PSNR=20.71  ER=1.93  t=820.3с
# ✓ lena_comet_kernel_pink.png  PSNR=20.78  ER=1.53  t=810.6с
# ✓ lena_defocus_kernel_brown.png  PSNR=26.72  ER=0.81  t=636.8с
# ✓ lena_defocus_kernel_clean.png  PSNR=27.44  ER=0.68  t=641.8с
# ✓ lena_defocus_kernel_gaussian.png  PSNR=26.49  ER=1.36  t=642.3с
# ✓ lena_defocus_kernel_impulse.png  PSNR=27.55  ER=1.69  t=648.1с
# ✓ lena_defocus_kernel_pink.png  PSNR=26.97  ER=1.21  t=655.6с
# ✓ lena_comet_kernel_poisson.png  PSNR=20.70  ER=1.54  t=967.8с
# ✓ lena_defocusmotion_kernel_brown.png  PSNR=25.33  ER=1.15  t=644.7с
# ✓ lena_defocusmotion_kernel_clean.png  PSNR=25.23  ER=1.00  t=653.4с
# ✓ lena_defocusmotion_kernel_gaussian.png  PSNR=24.98  ER=1.60  t=654.1с
# ✓ lena_defocusmotion_kernel_impulse.png  PSNR=26.46  ER=2.05  t=653.8с
# ✓ lena_defocus_kernel_poisson.png  PSNR=27.26  ER=1.15  t=805.4с
# ✓ lena_defocusmotion_kernel_pink.png  PSNR=25.73  ER=1.45  t=652.8с
# ✓ lena_heliod_kernel_brown.png  PSNR=20.28  ER=0.63  t=768.7с
# ✓ lena_heliod_kernel_clean.png  PSNR=20.97  ER=0.69  t=768.6с
# ✓ lena_defocusmotion_kernel_poisson.png  PSNR=26.09  ER=1.45  t=807.5с
# ✓ lena_heliod_kernel_gaussian.png  PSNR=20.59  ER=0.67  t=772.6с
# ✓ lena_heliod_kernel_impulse.png  PSNR=20.67  ER=0.70  t=771.8с
# ✓ lena_heliod_kernel_pink.png  PSNR=20.82  ER=0.74  t=769.6с
# ✓ lena_hookdefocus_kernel_brown.png  PSNR=21.88  ER=1.08  t=799.0с
# ✓ lena_hookdefocus_kernel_clean.png  PSNR=22.42  ER=1.16  t=804.2с
# ✓ lena_hookdefocus_kernel_gaussian.png  PSNR=22.40  ER=1.14  t=809.7с
# ✓ lena_heliod_kernel_poisson.png  PSNR=20.78  ER=0.66  t=924.9с
# ✓ lena_hookdefocus_kernel_impulse.png  PSNR=23.18  ER=1.34  t=810.7с
# ✓ lena_hookdefocus_kernel_pink.png  PSNR=22.06  ER=1.10  t=812.4с
# ✓ lena_linear_kernel_brown.png  PSNR=24.46  ER=0.72  t=582.5с
# ✓ lena_linear_kernel_gaussian.png  PSNR=24.90  ER=1.19  t=582.1с
# ✓ lena_linear_kernel_clean.png  PSNR=25.11  ER=0.76  t=587.1с
# ✓ lena_linear_kernel_impulse.png  PSNR=25.10  ER=1.27  t=580.8с
# ✓ lena_linear_kernel_pink.png  PSNR=24.64  ER=1.03  t=573.3с
# ✓ lena_hookdefocus_kernel_poisson.png  PSNR=22.17  ER=1.16  t=958.1с
# ✓ lena_linear_kernel_poisson.png  PSNR=24.80  ER=1.14  t=568.5с
# ✓ lena_pacman_kernel_brown.png  PSNR=22.07  ER=1.21  t=647.6с
# ✓ lena_pacman_kernel_clean.png  PSNR=23.38  ER=1.31  t=659.7с
# ✓ lena_pacman_kernel_gaussian.png  PSNR=22.95  ER=1.57  t=657.4с
# ✓ lena_pacman_kernel_impulse.png  PSNR=23.38  ER=1.57  t=653.6с
# ✓ lena_pacman_kernel_pink.png  PSNR=23.64  ER=1.41  t=654.7с
# ✓ lena_pacman_kernel_poisson.png  PSNR=22.47  ER=1.51  t=655.0с
# ✓ lena_wspiral_kernel_brown.png  PSNR=20.48  ER=0.96  t=759.4с
# ✓ lena_wspiral_kernel_clean.png  PSNR=21.13  ER=0.94  t=761.6с
# ✓ lena_wspiral_kernel_gaussian.png  PSNR=21.04  ER=0.75  t=762.6с
# ✓ lena_wspiral_kernel_impulse.png  PSNR=21.11  ER=0.77  t=761.4с
# ✓ lena_wspiral_kernel_pink.png  PSNR=20.95  ER=0.85  t=752.6с
# ✓ lena_wspiral_kernel_poisson.png  PSNR=21.23  ER=0.83  t=813.1с
# ✓ people_comet_kernel_brown.png  PSNR=20.51  ER=1.13  t=797.0с
# ✓ people_comet_kernel_clean.png  PSNR=20.21  ER=1.08  t=802.4с
# ✓ people_comet_kernel_gaussian.png  PSNR=20.55  ER=2.11  t=804.1с
# ✓ people_comet_kernel_impulse.png  PSNR=20.21  ER=2.53  t=800.5с
# ✓ people_comet_kernel_pink.png  PSNR=20.50  ER=1.80  t=788.4с
# ✓ people_comet_kernel_poisson.png  PSNR=20.73  ER=1.68  t=808.1с
# ✓ people_defocus_kernel_brown.png  PSNR=24.91  ER=0.59  t=633.5с
# ✓ people_defocus_kernel_clean.png  PSNR=25.62  ER=0.52  t=637.1с
# ✓ people_defocus_kernel_gaussian.png  PSNR=24.83  ER=1.17  t=635.7с
# ✓ people_defocus_kernel_impulse.png  PSNR=25.70  ER=1.58  t=634.9с
# ✓ people_defocus_kernel_pink.png  PSNR=25.12  ER=0.97  t=627.7с
# ✓ people_defocus_kernel_poisson.png  PSNR=25.35  ER=0.89  t=639.8с
# ✓ people_defocusmotion_kernel_brown.png  PSNR=23.03  ER=1.11  t=633.4с
# ✓ people_defocusmotion_kernel_clean.png  PSNR=23.83  ER=1.05  t=638.1с
# ✓ people_defocusmotion_kernel_gaussian.png  PSNR=23.48  ER=1.92  t=630.9с
# ✓ people_defocusmotion_kernel_impulse.png  PSNR=23.83  ER=2.23  t=632.7с
# ✓ people_defocusmotion_kernel_pink.png  PSNR=23.12  ER=1.69  t=632.9с
# ✓ people_defocusmotion_kernel_poisson.png  PSNR=23.51  ER=1.59  t=640.4с
# ✓ people_heliod_kernel_brown.png  PSNR=19.86  ER=0.69  t=757.6с
# ✓ people_heliod_kernel_clean.png  PSNR=19.87  ER=0.68  t=763.4с
# ✓ people_heliod_kernel_gaussian.png  PSNR=19.91  ER=0.68  t=764.3с
# ✓ people_heliod_kernel_impulse.png  PSNR=19.86  ER=0.71  t=762.2с
# ✓ people_heliod_kernel_pink.png  PSNR=20.04  ER=0.75  t=753.8с
# ✓ people_heliod_kernel_poisson.png  PSNR=19.84  ER=0.69  t=823.8с
# ✓ people_hookdefocus_kernel_brown.png  PSNR=19.84  ER=0.92  t=789.6с
# ✓ people_hookdefocus_kernel_clean.png  PSNR=20.27  ER=0.88  t=793.0с
# ✓ people_hookdefocus_kernel_gaussian.png  PSNR=20.06  ER=1.27  t=793.6с
# ✓ people_hookdefocus_kernel_impulse.png  PSNR=19.93  ER=1.45  t=791.4с
# ✓ people_hookdefocus_kernel_pink.png  PSNR=19.82  ER=1.10  t=787.1с
# ✓ people_linear_kernel_brown.png  PSNR=22.55  ER=0.80  t=572.8с
# ✓ people_linear_kernel_clean.png  PSNR=22.95  ER=0.76  t=581.0с
# ✓ people_linear_kernel_gaussian.png  PSNR=23.00  ER=1.24  t=575.2с
# ✓ people_hookdefocus_kernel_poisson.png  PSNR=20.56  ER=1.18  t=789.2с
# ✓ people_linear_kernel_impulse.png  PSNR=22.95  ER=1.21  t=576.0с
# ✓ people_linear_kernel_pink.png  PSNR=22.72  ER=1.05  t=571.0с
# ✓ people_linear_kernel_poisson.png  PSNR=22.95  ER=1.15  t=565.0с
# ✓ people_pacman_kernel_clean.png  PSNR=21.60  ER=1.23  t=664.4с
# ✓ people_pacman_kernel_brown.png  PSNR=20.61  ER=1.05  t=667.7с
# ✓ people_pacman_kernel_gaussian.png  PSNR=21.10  ER=1.62  t=664.8с
# ✓ people_pacman_kernel_impulse.png  PSNR=21.61  ER=1.68  t=664.2с
# ✓ people_pacman_kernel_pink.png  PSNR=21.03  ER=1.39  t=659.7с
# ✓ people_pacman_kernel_poisson.png  PSNR=21.01  ER=1.51  t=763.6с
# ✓ people_wspiral_kernel_brown.png  PSNR=19.83  ER=0.93  t=754.9с
# ✓ people_wspiral_kernel_clean.png  PSNR=20.55  ER=1.11  t=755.8с
# ✓ people_wspiral_kernel_gaussian.png  PSNR=20.02  ER=0.79  t=756.7с
# ✓ people_wspiral_kernel_impulse.png  PSNR=20.43  ER=0.76  t=750.8с
# ✓ people_wspiral_kernel_pink.png  PSNR=20.11  ER=0.93  t=684.4с
# ✓ people_wspiral_kernel_poisson.png  PSNR=20.52  ER=0.88  t=469.6с
#
# ────────────────────────────────────────────────────────────
# Обработано: 192/192  |  CSV: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\Set12\results_Logrifmic image prior - primal dual_Set12.csv
#     dataset                      distorted_file image_name kernel_name  \
# 0     Set12      barbara_comet_kernel_brown.png    barbara       comet
# 1     Set12       barbara_comet_kernel_pink.png    barbara       comet
# 2     Set12    barbara_comet_kernel_impulse.png    barbara       comet
# 3     Set12      barbara_comet_kernel_clean.png    barbara       comet
# 4     Set12   barbara_comet_kernel_gaussian.png    barbara       comet
# ..      ...                                 ...        ...         ...
# 187   Set12     people_wspiral_kernel_clean.png     people     wspiral
# 188   Set12  people_wspiral_kernel_gaussian.png     people     wspiral
# 189   Set12   people_wspiral_kernel_impulse.png     people     wspiral
# 190   Set12      people_wspiral_kernel_pink.png     people     wspiral
# 191   Set12   people_wspiral_kernel_poisson.png     people     wspiral
#
#           noise_name kernel_shape  time_sec  \
# 0       kernel_brown     (35, 35)   928.063
# 1        kernel_pink     (35, 35)   931.478
# 2     kernel_impulse     (35, 35)   932.470
# 3       kernel_clean     (35, 35)   934.881
# 4    kernel_gaussian     (35, 35)   936.576
# ..               ...          ...       ...
# 187     kernel_clean     (31, 31)   755.791
# 188  kernel_gaussian     (31, 31)   756.711
# 189   kernel_impulse     (31, 31)   750.789
# 190      kernel_pink     (31, 31)   684.398
# 191   kernel_poisson     (31, 31)   469.643
#
#                                          restored_path  \
# 0    D:\for_proga\franework_deconvolution\framework...
# 1    D:\for_proga\franework_deconvolution\framework...
# 2    D:\for_proga\franework_deconvolution\framework...
# 3    D:\for_proga\franework_deconvolution\framework...
# 4    D:\for_proga\franework_deconvolution\framework...
# ..                                                 ...
# 187  D:\for_proga\franework_deconvolution\framework...
# 188  D:\for_proga\franework_deconvolution\framework...
# 189  D:\for_proga\franework_deconvolution\framework...
# 190  D:\for_proga\franework_deconvolution\framework...
# 191  D:\for_proga\franework_deconvolution\framework...
#
#                                            kernel_path  \
# 0    D:\for_proga\franework_deconvolution\framework...
# 1    D:\for_proga\franework_deconvolution\framework...
# 2    D:\for_proga\franework_deconvolution\framework...
# 3    D:\for_proga\franework_deconvolution\framework...
# 4    D:\for_proga\franework_deconvolution\framework...
# ..                                                 ...
# 187  D:\for_proga\franework_deconvolution\framework...
# 188  D:\for_proga\franework_deconvolution\framework...
# 189  D:\for_proga\franework_deconvolution\framework...
# 190  D:\for_proga\franework_deconvolution\framework...
# 191  D:\for_proga\franework_deconvolution\framework...
#
#                                         gt_kernel_path  \
# 0    D:\for_proga\franework_deconvolution\framework...
# 1    D:\for_proga\franework_deconvolution\framework...
# 2    D:\for_proga\franework_deconvolution\framework...
# 3    D:\for_proga\franework_deconvolution\framework...
# 4    D:\for_proga\franework_deconvolution\framework...
# ..                                                 ...
# 187  D:\for_proga\franework_deconvolution\framework...
# 188  D:\for_proga\franework_deconvolution\framework...
# 189  D:\for_proga\franework_deconvolution\framework...
# 190  D:\for_proga\franework_deconvolution\framework...
# 191  D:\for_proga\franework_deconvolution\framework...
#
#                                          original_path     psnr    ssim  \
# 0    D:\for_proga\franework_deconvolution\framework...  19.2216  0.3838
# 1    D:\for_proga\franework_deconvolution\framework...  19.7334  0.4168
# 2    D:\for_proga\franework_deconvolution\framework...  19.3897  0.4320
# 3    D:\for_proga\franework_deconvolution\framework...  19.3408  0.4309
# 4    D:\for_proga\franework_deconvolution\framework...  19.3562  0.4294
# ..                                                 ...      ...     ...
# 187  D:\for_proga\franework_deconvolution\framework...  20.5500  0.4076
# 188  D:\for_proga\franework_deconvolution\framework...  20.0160  0.3594
# 189  D:\for_proga\franework_deconvolution\framework...  20.4288  0.3896
# 190  D:\for_proga\franework_deconvolution\framework...  20.1088  0.3340
# 191  D:\for_proga\franework_deconvolution\framework...  20.5232  0.3977
#
#      psnr_blurred  ssim_blurred  error_ratio
# 0         19.2056        0.4131       1.1769
# 1         19.2182        0.3774       1.4577
# 2         19.1324        0.4189       1.8939
# 3         19.3697        0.4459       1.2329
# 4         19.2238        0.3728       1.6148
# ..            ...           ...          ...
# 187       20.3769        0.3971       1.1122
# 188       20.1978        0.3310       0.7858
# 189       20.0918        0.3687       0.7604
# 190       20.1964        0.3342       0.9253
# 191       20.2641        0.3527       0.8754
#
# [192 rows x 16 columns]
#   Генерация комплексных изображений (192 шт.). Пожалуйста, подождите...
#   Готово! Сохранено 192 изображений в: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\Set12\complex_plots

# %% [markdown]
# ## Финальная сводка: графики и TeX для одного алгоритма
#
# Эта ячейка строит все индивидуальные графики по накопленным данным из `ALL_DATASET_RESULTS`.
#
# Графики:
# - 4. PSNR/SSIM в зависимости от итераций (если доступно)
# - 5. Сходимость ядра (если доступно)
# - 6. Гистограмма распределения error ratio
# - 7. Зависимость от шума (если в именах файлов есть информация)
# - 8. Зависимость от размера ядра
# - 2. Success Rate vs Error Ratio (если есть GT ядра)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# ЯЧЕЙКА 3. Финальная сводка для одного алгоритма
# ══════════════════════════════════════════════════════════════════════════════

# Объединяем все результаты
df_all = pd.concat([r['df'] for r in ALL_DATASET_RESULTS], ignore_index=True)
print(f"Всего обработано изображений: {len(df_all)}\n")

TEX_DIR = ALG_RESULTS_DIR / "tex"
TEX_DIR.mkdir(exist_ok=True)
FIG_DIR = ALG_RESULTS_DIR / "figures"
FIG_DIR.mkdir(exist_ok=True)

# ─── 6. Гистограмма распределения отношения ошибки ───────────────────────────
vis.plot_error_ratio_histogram_single(
    df_all['error_ratio'], ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 2. Доля успешных / отношение ошибки ─────────────────────────────────────
vis.plot_success_rate_single(
    df_all['error_ratio'], ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 3. Столбчатая диаграмма PSNR / SSIM по изображениям ─────────────────────
vis.plot_psnr_ssim_bars_single(
    df_all, ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 8. Зависимость от размера ядра ──────────────────────────────────────────
vis.plot_kernel_size_dependency_single(
    df_all, ALGORITHM_LABEL, fig_dir=FIG_DIR, tex_dir=TEX_DIR
)

# ─── 10. Таблица средних метрик по наборам данных ─────────────────────────────
df_summary = vis.build_summary_single(
    ALL_DATASET_RESULTS, ALGORITHM_LABEL, tex_dir=TEX_DIR
)
display(df_summary)

# Сохраняем объединённый CSV
df_all.to_csv(ALG_RESULTS_DIR / f"all_results_{ALGORITHM_LABEL}.csv", index=False)
print(f"\nОбщий CSV: {ALG_RESULTS_DIR / f'all_results_{ALGORITHM_LABEL}.csv'}")
# Out:
# Всего обработано изображений: 384
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\tex\error_ratio_histogram.tex
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\tex\success_rate.tex
# 2026-04-17 05:02:44,034 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-17 05:02:44,034 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-17 05:02:44,034 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-17 05:02:44,043 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\tex\psnr_ssim_bar.tex
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\tex\kernel_size_dependency.tex
#   TeX сохранён: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\tex\summary_table.tex
#      Набор данных  Количество искаженных изображений Размер изображения  \
# 0           Levin                                192            255x255
# 1           Set12                                192            512x512
# 2  ВСЕ (Суммарно)                                384          Различные
#
#    PSNR (исх.)  Среднее (PSNR) Δ PSNR  Медиана (PSNR)  Максимум (PSNR)  \
# 0        20.65           21.50  +0.86           20.33            29.47
# 1        21.82           21.87  +0.05           21.08            27.55
# 2        21.23           21.69  +0.45           20.76            29.47
#
#               Лучший случай (PSNR)  Минимум (PSNR)  ... SSIM (исх.)  \
# 0   boy_defocus_kernel_impulse.png           15.84  ...      0.4927
# 1  lena_defocus_kernel_impulse.png           18.79  ...      0.4896
# 2   boy_defocus_kernel_impulse.png           15.84  ...      0.4911
#
#    Среднее (SSIM)   Δ SSIM Медиана (SSIM)  Максимум (SSIM)  \
# 0          0.5403  +0.0477         0.5205           0.9052
# 1          0.5166  +0.0270         0.5141           0.7987
# 2          0.5285  +0.0373         0.5158           0.9052
#
#                Лучший случай (SSIM) Минимум (SSIM)  \
# 0  drawing_defocus_kernel_clean.png          0.243
# 1   lena_defocus_kernel_impulse.png          0.305
# 2  drawing_defocus_kernel_clean.png          0.243
#
#               Худший случай (SSIM) Отн. ошибки  Время (с)
# 0   house_wspiral_kernel_brown.png        1.24      95.49
# 1  people_wspiral_kernel_brown.png        1.19     735.00
# 2   house_wspiral_kernel_brown.png        1.21     415.24
#
# [3 rows x 21 columns]
# Общий CSV: D:\for_proga\franework_deconvolution\framework (9)\presentation_graphics\Logrifmic_image_prior_-_primal_dual\all_results_Logrifmic image prior - primal dual.csv
